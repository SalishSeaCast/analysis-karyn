# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import netCDF4 as nc
import xarray as xr
import datetime as dt
from salishsea_tools import evaltools as et, viz_tools, places
import gsw 
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import matplotlib.dates as mdates
import cmocean as cmo
import scipy.interpolate as sinterp
import math
from scipy import io
import pickle
import cmocean
from salishsea_tools import Keegan_eval_tools as ket
import json
from collections import OrderedDict
from matplotlib.colors import LogNorm
import arrow
import glob
import datetime
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
from matplotlib.dates import HourLocator, MonthLocator, YearLocator

fs=16
mpl.rc('xtick', labelsize=fs)
mpl.rc('ytick', labelsize=fs)
mpl.rc('legend', fontsize=fs)
mpl.rc('axes', titlesize=fs)
mpl.rc('axes', labelsize=fs)
mpl.rc('figure', titlesize=fs)
mpl.rc('font', size=fs)
mpl.rc('font', family='sans-serif', weight='normal', style='normal')

import warnings
#warnings.filterwarnings('ignore')
from IPython.display import Markdown, display

# %matplotlib inline

# %%
with nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/mesh_mask202108.nc') as mesh:
    tmask=np.copy(mesh.variables['tmask'][0,:,:,:])
    navlat=np.copy(mesh.variables['nav_lat'][:,:])
    navlon=np.copy(mesh.variables['nav_lon'][:,:])

# %%
ij,ii=places.PLACES['S3']['NEMO grid ji']

# %%
ii
# Out:
# 258

# %%
yearList = [2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

data = 'month-avg.202111'
#year = '2014'
month = '01'
file = 'biol'

for year in yearList:
    files=[glob.glob(f'/results2/SalishSea/{data}/SalishSeaCast_1m_{file}_T_*{year}*{month:02d}01_*{year}*{month:02d}??.nc')[0] for year in yearList for month in range(1,13) ]

# %%
clim=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_month_climatology_biol_T_20070101_20230831.nc')

# %%
clim.variables.keys()
# Out:
# dict_keys(['nitrate', 'ammonium', 'silicon', 'diatoms', 'flagellates', 'microzooplankton', 'dissolved_organic_nitrogen', 'particulate_organic_nitrogen', 'biogenic_silicon', 'mesozooplankton', 'depth', 'gridY', 'gridX', 'month'])

# %%
## Gathering metadata but still not opening the files
dsfiles = xr.open_mfdataset(
        files,
        #chunks=chunk_size,
        compat="override",
        coords="minimal",
        data_vars="minimal",
        drop_variables=['ammonium', 'silicon', \
                        'dissolved_organic_nitrogen', \
                        'particulate_organic_nitrogen', 'biogenic_silicon', ],
        parallel=True,
        engine='netcdf4'
    )

# %%
tt=np.array(dsfiles.time)
mod_depth=np.array(dsfiles.depth)

mod_nitrate=(dsfiles.nitrate.isel(gridY=ij,gridX=ii))
mod_nitrate = (np.array(mod_nitrate))
mod_nitrate = np.ma.masked_equal(mod_nitrate,0).T

# %%
is_nan = np.isnan(mod_nitrate)
print(is_nan)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]

# %%
start= dt.datetime(2007,1,1)
end=dt.datetime(2022,12,31)

# %%
date_range=(start,end)

# %%
tt.min()
# Out:
# numpy.datetime64('2007-01-15T12:00:00.000000000')

# %%
ax=ket.hovmoeller(mod_nitrate, mod_depth, tt,(0,50),date_range, title='Nitrate - Central Strait of Georgia ',
               var_title='umol N',vmax=0,vmin=5,cmap=cmo.cm.thermal)



ax.set_ylabel('Depth (m)')
ax.set_xlabel('')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# Out:
# /ocean/ksuchy/MOAD/tools/SalishSeaTools/salishsea_tools/Keegan_eval_tools.py:816: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis="x", nbins=20)

# %%
### This isn't pretty, but I could not figure out how to repeat the climatology for all years in the time series
### np.repeat did not repeat on the proper axes

n_year1=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year2=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)                
n_year3=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)                
n_year4=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)                
n_year5=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)                
n_year6=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)  
n_year7=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year8=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year9=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year10=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year11=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year12=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year13=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year14=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year15=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)
n_year16=clim['nitrate'][:,:,ij,ii].swapaxes(1,0) 
#n_year17=clim['nitrate'][:,:,ij,ii].swapaxes(1,0)

# %%
## Concatentate all of the above files to get sequential climatologies across the time series
clim_nitrate=np.concatenate((n_year1,n_year2,n_year3,n_year4,n_year5,n_year6, n_year7, n_year8,n_year9,n_year10,\
                         n_year11,n_year12,n_year13,n_year14,n_year15,n_year16), axis=1)  #,n_year17

# %%
ax=ket.hovmoeller(mod_nitrate-clim_nitrate, mod_depth, tt,(0,200),date_range, title='B. Nitrate Anomalies - Central Strait of Georgia ',
               var_title='umol N',vmax=-10,vmin=10,cmap=cmo.cm.balance)



ax.set_ylabel('Depth (m)')
ax.set_xlabel('')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

#contour_value = 9 
#contour = ax.contour(tt, mod_depth, mod_votemper, levels=[contour_value], colors='mediumslateblue')

# %%
(mod_nitrate-clim_nitrate).min()
# Out:
# nan

# %%
(mod_nitrate-clim_nitrate).max()
# Out:
# nan

# %%
mean_anomalies=np.mean(mod_nitrate-clim_nitrate,axis=0)

# %%
mean_anomalies
# Out:
# masked_array(data=[0.712029961978688, 0.8082233877742991,
#                    1.6705746370203354, 0.48500678118537455,
#                    -0.11977038663976333, 0.8513570673325482,
#                    1.668471841251149, 0.6424107832067153,
#                    0.10636559654684628, 2.5638409782858456,
#                    0.5780212738934685, 0.9089495153988109,
#                    0.9427564284380745, 0.4001626968383789,
#                    0.36985282336964326, -0.32187795639038086,
#                    1.0835129232967602, --, 0.7106016383451574,
#                    2.6180933784036076, -0.2556602814618279,
#                    1.376493117388557, 1.5307406257180607,
#                    0.7300567626953125, 0.9125213623046875,
#                    0.7990161671357996, 0.9496314104865579,
#                    1.357711118810317, 1.0482171002556295,
#                    -0.7544068729176241, -0.781578400555779,
#                    0.7767565110150505, 0.46342384113984947,
#                    -0.19726105297313018, 1.614892286412856,
#                    0.26590386558981505, 0.7547822279088637,
#                    0.38534119549919577, 0.6603246576645795,
#                    0.9439018473905676, 0.8993985793169808,
#                    1.4271004620720358, -1.4870298049029183,
#                    -0.7617703606100643, 1.0441979800953585,
#                    0.3327810343574075, 0.07145819944493911,
#                    0.9189683689790613, 0.20051170797909007,
#                    0.27440553552964153, 1.842480266795439,
#                    1.328236748190487, 1.684973211849437,
#                    -0.43290915208704334, 0.16486402118907256,
#                    0.46634640413172107, 0.8424007191377527,
#                    0.6418110342586741, 0.8126727833467371,
#                    0.35664019865148205, 0.9395681830013499,
#                    0.9930828318876379, 2.1372709835276886,
#                    1.4717145807602827, 0.15835924709544463,
#                    1.9080242830164291, 1.9011589499080883,
#                    0.8117728513829848, -0.6743083841660443,
#                    0.3022766393773696, 0.720944741192986,
#                    1.2201396717744715, 0.313810011919807,
#                    1.1923637390136719, 1.0625678791719324,
#                    0.37756886201746326, 1.2275590335621553,
#                    0.7570711023667279, -0.6302107642678654,
#                    1.6077386070700252, 0.4895453172571519,
#                    -1.195211747113396, -0.6451279135311351,
#                    0.2277038798612707, 0.1797323226928711,
#                    0.5892474791582893, 0.8921030829934513,
#                    0.906440398272346, 0.7230137095731848,
#                    -0.7931796803193933, -0.44169050104477825,
#                    -2.3589369829963234, -1.2337552238913143,
#                    0.1424067721647375, -0.856339735143325,
#                    -1.0203703712014591, -1.4086511275347542,
#                    -1.6227358649758732, -2.758060904110179,
#                    -1.7156541487749886, -0.857146094827091,
#                    -0.47144289577708526, -1.0471510045668657,
#                    -0.283601536470301, 0.8498048782348633,
#                    -0.7206659878001493, -0.5213990491979262,
#                    -0.10222249872544233, -0.37807290694292855,
#                    -0.6514142541324391, -0.10875407387228574,
#                    -2.9619926003848804, -1.7578688228831572,
#                    -0.00363383924259859, 0.7897175620583927,
#                    -1.51226806640625, -0.4204588216893813,
#                    1.574539857752183, -0.1028129353242762,
#                    -1.130577984978171, -1.138604669009938,
#                    -0.9155204436358284, 0.9336414898143095,
#                    0.9083485322840074, -0.7353271035587087,
#                    -1.1830121208639706, -0.49841908847584443,
#                    -0.6257364048677332, -1.3934985890107996,
#                    -0.5625764622407801, 0.17627334594726562,
#                    -0.690480624928194, -0.11433808943804573,
#                    -0.8252420425415039, -1.7383933347814224,
#                    0.38784921870512123, -1.2683722552131205,
#                    0.07602273015414968, 0.30703042535220876,
#                    -0.39742643692914176, 0.6333753361421472,
#                    -1.0498302684110754, 0.11617862477022059,
#                    0.16073193269617417, -0.5061003741096047,
#                    -0.3902695038739373, -2.5052288279813877,
#                    -1.333035525153665, -1.2438522787655102,
#                    -0.9251038607429055, 0.5762481689453125,
#                    0.27455733804141774, 0.2724631533903234,
#                    -1.2514260235954733, -1.6240963655359604,
#                    -0.41965119978960824, 0.27004556094898896,
#                    -0.23625805798698873, -2.0203942691578582,
#                    -2.1090247210334327, -0.6740167842191809,
#                    0.272156042211196, 0.09095469643087949,
#                    0.02135661770315731, -0.35033175524543314,
#                    -1.0931558048023897, -0.5411397148581112,
#                    -0.3776903713450712, -0.28963397530948415,
#                    -0.5099297130809111, -0.13366253235760858,
#                    -2.3202936509076286, -0.4947512009564568,
#                    -0.5836439693675322, -1.0440055622774012,
#                    -0.19733687008128448, 0.9712606317856732,
#                    1.351444917566636, -0.48749373940860524,
#                    -0.969685947193819, -0.9589913312126609,
#                    -0.9683931014117073, -0.8670988643870634,
#                    -0.47377636853386373, 1.2095349255730123,
#                    1.156607235179228, 0.2730733086081112,
#                    -0.6186892565558938, -1.3448235006893383,
#                    -2.215463077320772, -0.8427782619700712,
#                    -0.07841306574204389],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False,  True, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value=1e+20)

# %%
np.shape(mod_nitrate)
# Out:
# (40, 192)

# %%
### All depths 

fig,ax=plt.subplots(1,1,figsize=(10,2.5))
x=tt
y=mean_anomalies

ax.plot(x,y,color='k')
ax.set_ylim(-8,8)
ax.axhline(y=0,color='k',linestyle='-')

ax.fill_between(x,y,where=y<0, color='blue')
ax.fill_between(x,y,where=y>0, color='red')

ax.set_title('Nitrate Anomalies - Central Strait of Georgia')

plt.show()

# %%
mean_anomalies_surf=np.mean(mod_nitrate[0:23]-clim_nitrate[0:23],axis=0) ##20 = 25m depth

# %%
np.shape(mean_anomalies_surf)
# Out:
# (192,)

# %%
np.shape(tt)
# Out:
# (192,)

# %%
## mean anomalies for surface (0-25m) only

fig,ax=plt.subplots(1,1,figsize=(10,2.5))
x=tt
y=mean_anomalies_surf


ax.plot(x,y,color='k')
ax.set_ylim(-8,8)
plt.grid(True)
ax.minorticks_on()
#plt.grid(which='major',axis ='y', linewidth='1', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks
hloc = YearLocator(1)
ax.xaxis.set_minor_locator(hloc)

ax.axhline(y=0,color='k',linestyle='-')


ax.fill_between(x,y,where=y<0, color='blue')
ax.fill_between(x,y,where=y>0, color='red')

ax.set_title('Nitrate Anomalies - Central Strait of Georgia (0-50 m)')
#plt.grid()
plt.show()

# %%
mean_anomalies_below25=np.mean(mod_nitrate[23:28]-clim_nitrate[23:28],axis=0)

# %%
## mean anomalies for 25 m and below (33 is the last depth grid layer at this location)

fig,ax=plt.subplots(1,1,figsize=(10,2.5))
x=tt
y=mean_anomalies_below25

ax.plot(x,y,color='k')
ax.set_ylim(-8,8)
ax.axhline(y=0,color='k',linestyle='-')

ax.fill_between(x,y,where=y<0, color='blue')
ax.fill_between(x,y,where=y>0, color='red')
plt.grid(True)
ax.minorticks_on()
#plt.grid(which='major',axis ='y', linewidth='1', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks
hloc = YearLocator(1)
ax.xaxis.set_minor_locator(hloc)
ax.set_title('Nitrate Anomalies - Central Strait of Georgia (50-150 m)')

plt.show()

# %%
mean_anomalies_deep=np.mean(mod_nitrate[28:]-clim_nitrate[28:],axis=0) ##28=150m depth

# %%
## mean anomalies for 150 m and below (33 is the last depth grid layer at this location)

fig,ax=plt.subplots(1,1,figsize=(10,2.5))
x=tt
y=mean_anomalies_deep

ax.plot(x,y,color='k')
ax.set_ylim(-8,8)
ax.axhline(y=0,color='k',linestyle='-')
plt.grid(True)
ax.minorticks_on()
#plt.grid(which='major',axis ='y', linewidth='1', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks
hloc = YearLocator(1)
ax.xaxis.set_minor_locator(hloc)
ax.fill_between(x,y,where=y<0, color='blue')
ax.fill_between(x,y,where=y>0, color='red')

ax.set_title('Nitrate Anomalies - Central Strait of Georgia (150m - Bottom)')

plt.show()
