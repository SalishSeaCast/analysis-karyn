# %% [markdown]
# ### This notebook is for plotting the main figures used in the SOPO report/presentation. Specific notebooks where calculations can be found are listed below

# %%
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import numpy as np
import pandas as pd

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>

<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
plt.rcParams.update({'font.size': 12, 'axes.titlesize': 'medium'})

# %% [markdown]
# ## Import NPGO Index file

# %%
## Can either import NPGO values or calculate annual values elsewhere and create an array for plotting. 

df = pd.read_csv('/ocean/ksuchy/MOAD/analysis-karyn/notebooks/SOPO/SOPO_2025/NPGO.csv', index_col=0,header=0)

# %%
df.index.name = "YEAR"
df = df.apply(pd.to_numeric) # convert all columns of DataFrame
#df = df[:-1]

# %% [markdown]
# ### Select years 2007 to 2025 for SOPO report

# %%
df.loc[2007:2026]
# Out:
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# YEAR
# 2007 -0.243309 -0.729927 -0.182149  0.384615  0.144928  1.230000  1.230000
# 2008  0.179856  1.140000  1.370000  1.400000  1.740000  1.280000  1.430000
# 2009  0.138313  0.110011  0.302115  0.240385  0.180180  0.270270  0.178571
# 2010  2.060000  1.840000  1.650000  1.180000  1.870000  1.240000  1.150000
# 2011  0.310559  0.181818  1.200000  0.167785  1.390000  1.110000  1.040000
# 2012  0.119904  0.115875  1.120000  1.930000  1.630000  1.940000  1.860000
# 2013  1.230000  1.200000  0.155521  0.210084  0.117371  0.137552  0.221729
# 2014 -0.256410 -0.374532 -0.220264 -0.161812  0.440529 -0.239808 -0.746269
# 2015 -0.181488 -1.270000 -1.400000 -1.380000 -0.138889 -1.250000 -1.470000
# 2016  0.106724  0.436681  0.211864 -0.250000 -0.146628 -0.104384 -0.205339
# 2017  1.622642 -0.149701 -0.112108 -0.884956 -0.219298 -0.341297 -0.225225
# 2018 -1.500000 -2.230000 -2.030000 -2.060000 -1.920000 -1.940000 -1.570000
# 2019 -0.116293 -2.560000 -1.990000 -2.160000 -1.860000 -2.350000 -2.160000
# 2020 -1.520000 -2.320000 -1.830000 -1.880000 -1.360000 -1.890000 -2.040000
# 2021 -0.580000 -1.200000 -0.860000 -1.890000 -0.860000 -0.550000 -0.690000
# 2022 -1.410000 -2.090000 -1.100000 -0.640000 -0.410000 -0.670000 -0.480000
# 2023 -1.690000 -2.240000 -2.780000 -1.950000 -1.290000 -1.320000 -1.410000
# 2024 -1.630000 -1.630000 -1.950000 -2.510000 -2.250000 -1.630000 -1.710000
# 2025  2.570000 -2.560000 -1.450000 -1.570000 -9.110000 -1.500000 -9.140000
#
#            AUG       SEP       OCT       NOV       DEC
# YEAR
# 2007  1.430000  0.110011  1.270000  0.137363  0.218341
# 2008  2.140000  2.230000  1.770000  1.970000  0.227273
# 2009  0.139276  0.102669  1.150000  1.050000  1.060000
# 2010  1.080000  1.000000  1.610000  0.101215  0.128370
# 2011  1.040000  1.330000  1.200000  0.267380  0.757576
# 2012  1.730000  1.360000  1.870000  1.400000  1.200000
# 2013  0.195312  0.256410 -0.680272 -0.124224 -1.450000
# 2014 -0.183486 -0.128700  0.235849  0.320513 -0.280899
# 2015 -1.930000 -2.100000 -1.310000 -2.250000 -1.110000
# 2016 -0.183824 -0.129199  0.284091  1.160000 -1.540000
# 2017 -0.188324 -0.190114 -1.410000 -2.060000 -2.690000
# 2018 -2.120000 -2.320000 -2.340000 -1.770000 -1.020000
# 2019 -2.060000 -2.520000 -2.580000 -3.370000 -2.540000
# 2020 -1.360000  1.250000 -1.830000 -2.590000 -1.330000
# 2021 -0.960000 -0.670000 -0.060000 -0.300000 -1.990000
# 2022 -0.480000 -1.120000 -1.890000 -2.120000 -2.560000
# 2023 -1.390000 -1.760000 -1.090000 -1.850000 -1.910000
# 2024 -2.030000 -2.100000 -2.100000 -2.120000 -1.580000
# 2025 -1.100000 -1.610000 -2.000000 -1.730000 -2.940000

# %%
NPGO = df.loc[2007:2026].to_numpy().flatten()

# %% [markdown]
# ### Get date into proper format

# %%
date = []
for year in range(2007, 2025):
    for month in range(1, 13):
        index = df.index == str(year)
        date.append(datetime(year, month, 1))
date = np.array(date)

# %% [markdown]
# ## Plot NPGO Index vs. monthly Central SoG diatom anomalies

# %%
## Annual NPGO values
NPGO_Annual=[0.416655983,
1.406427404,
0.410149171,
1.242465357,
0.832926488,
1.356314911,
0.122457003,
-0.132940854,
-1.315864758,
-0.030001073,
-0.570698404,
-1.901666667,
-2.188857716,
-1.558333333,
-0.884166667,
-1.2475,
-1.723333333,
-1.936666667,
-2.678333333]

# %%
## Values are from calculations in Diatoms_SOPO2025_CentralSoG_v202111.ipynb

Diatom_Critical_Anom=[0.9587065146964662,
                      3.785497592122365,
                      0.8896491349344053,
                      3.4246816726590907,
                      0.03985877809441973,
                      2.6829948384908633,
                      1.9587023692838912,
                      -2.231737575765452,
                      -2.0549345185938357,
                      0.2508894109322881,
                      -1.9942306040694913,
                      -2.29230019142663,
                      -0.6503592176858035,
                      -2.5310264467240593,
                      -1.7844261839645608,
                      -1.2502707398637156,
                      -0.7150275183785162,
                      0.5480416700217923,
                      0.9652910152364171]

# %%
## Values are from calculations in Winds2007-2025_CentralSoGonly.ipynb

Spring_Wind_Anom=[0.313348356567527,
                  0.16326290734877702,
                  0.5397550897625143,
                  0.5411509510702945,
                  0.5330507593181784,
                  0.6028301553753073,
                  -0.043610668497576555,
                  0.04235417016615983,
                  -0.4321954412433451,
                  0.2583057718303854,
                  -0.1478838287962425,
                  -0.7762175563149598,
                  -0.3038111689858578,
                  -0.41522893937160044 ,
                  -0.05239877732326015,
                  -0.29358015091945155,
                  -0.44797847381780986,
                  0.055188574991922756,
                  -0.13634173116096804]

# %%
## Values are from calculations in SST_SOPO2025_CentralSoG_v202111.ipynb

Spring_SST_Anom=[0.08808263436019104,
                 -0.809850172326934,
                 -0.22004180549952146 ,
                 -0.772601040925716,
                 -0.8886991054962401,
                 -1.1271376007793013,
                 -0.15047574437582512 ,
                 0.3303583044416083 ,
                 0.9766025278014236,
                 0.9582753128039467,
                 -0.035462680843830086,
                 0.6169147529485954,
                 0.4650382279883303,
                 0.2999951688896907,
                 0.4669688583361733,
                 -0.5781209388952817,
                 0.4192467963329669,
                 -0.2774291455728779,
                 0.23833565081259245
                ]

# %% [markdown]
# ## Plot Annual NPGO Index vs. Spring SST and Wind Anomalies

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))
x=['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
   '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']

ax2 = ax1.twinx()

ax1.plot(x, Spring_Wind_Anom,marker='^', label='Spring Wind Anomalies', color='k', zorder=5)
ax2.plot(x, Spring_SST_Anom,marker='s', linestyle='-.', label='Spring SST Anomalies',
         color='darkviolet', zorder=5)
ax1.set_title('', fontsize=18)  
ax1.legend(frameon=False, loc=2, fontsize=12)
ax1.set_ylim(-1,1)
ax1.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax1.set_ylabel('Wind Speed (m s$^{-1}$)', fontsize=12,)
ax1.axhline(y=0, color='lightgrey', linestyle='-', zorder=1)
ax2.axhline(y=0,color='lightgrey',linestyle='-',zorder=1)
ax2.legend(frameon=False, loc=4, fontsize=12)
ax2.set_ylim(-1.5,1.5)
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax2.set_ylabel('SST (Degrees C)', fontsize=12)
# Out:
# Text(0, 0.5, 'SST (Degrees C)')

# %% [markdown]
# ## Plot Annual NPGO Index vs. Spring SST and Wind Anomalies & May-July Diatom Anomalies

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))
ax2 = ax1.twinx()

ax1.plot(x, Spring_Wind_Anom,marker='^', label='Spring Wind Anomalies', color='k', zorder=100)
ax1.plot(x, Spring_SST_Anom,marker='s', linestyle='-.', label='Spring SST Anomalies',
         color='darkviolet', zorder=70)
ax1.set_title('',fontsize=18)
ax1.legend(frameon=False, loc=2, fontsize=12)
ax1.set_ylim(-1.5,1.5)
ax1.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax1.set_ylabel('Wind Speed (m s$^{-1}$)\nSST (Degrees C)', fontsize=12,)
ax1.axhline(y=0,color='lightgrey', linestyle='-')

ax2.bar(x, Diatom_Critical_Anom, color='limegreen', alpha=0.5, width=.75, zorder=50,
        label='Diatom Anomalies (May-July)')
ax2.legend(frameon=False, loc=4, fontsize=12)
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax2.axhline(y=0,color='lightgrey', linestyle='-')
ax2.set_ylabel('Diatom Biomass (mmol N m$^{-2}$)', fontsize=12)
ax2.set_ylim(-6,6)

fig.savefig('Interannual_Anomalies_2025.png');

# %% [markdown]
# ## Plot Annual NPGO Index vs. Critical Period for salmon (May-Jun) Diatom Anomalies

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))

ax2 = ax1.twinx()
ax1.bar(x, NPGO_Annual, width=.75, color='darkgrey',label='NPGO Index')

ax1.set_ylim(-4,4)
ax2.plot(x,Diatom_Critical_Anom,color='green',marker='o',markersize=8,linewidth=2.5,label='Diatom Anomalies (May-July)')
ax2.set_ylim(-10,10)
ax1.set_ylabel('NPGO Index')
ax2.set_ylabel('Diatom Anomalies (mmol N m$^{-2}$)')
ax1.axhline(y=0,color='k')

ax1.legend(frameon=False,loc=2)
ax2.legend(frameon=False,loc=1);
