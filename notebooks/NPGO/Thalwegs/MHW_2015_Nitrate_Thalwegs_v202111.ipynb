# %%
import numpy as np
import matplotlib.pyplot as plt
from salishsea_tools import viz_tools, places, visualisations
import netCDF4 as nc # unless you prefer xarray
import datetime as dt
import os
import glob
import cmocean

from IPython.display import Markdown, display
# %matplotlib inline

# %% [raw]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
clim=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_month_climatology_biol_T_20070101_20230831.nc')

# %% [markdown]
# ### Load a file from the 202111 hindcast

# %%
f1=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150101_20150131.nc')

# %%
print(f1.variables.keys())
# Out:
# dict_keys(['nitrate', 'ammonium', 'silicon', 'diatoms', 'flagellates', 'microzooplankton', 'dissolved_organic_nitrogen', 'particulate_organic_nitrogen', 'biogenic_silicon', 'mesozooplankton', 'depth', 'gridY', 'gridX', 'time'])

# %% [markdown]
# ### Thalweg plot
#   method using contour_thalweg from visualisations.py in tools repo

# %%
#open bathy file and meshmask
fbathy=nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/bathymetry_202108.nc')

fmesh=nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/mesh_mask202108.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f1.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('January 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201501.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f2=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150201_20150228.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f2.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('February 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201502.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f3=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150301_20150331.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f3.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('March 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201503.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f4=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150401_20150430.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f4.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('April 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201504.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f5=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150501_20150531.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f5.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('May 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201505.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f6=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150601_20150630.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f6.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('June 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201506.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f7=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150701_20150731.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f7.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('July 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201507.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f8=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150801_20150831.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f8.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('August 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201508.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f9=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20150901_20150930.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f9.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('September 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201509.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f10=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20151001_20151031.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f10.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('October 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201510.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f11=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20151101_20151130.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f11.variables['nitrate'][0,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('November 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201511.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f12=nc.Dataset('/results2/SalishSea/month-avg.202111/SalishSeaCast_1m_biol_T_20151201_20151231.nc')

# %%
il=0
fig,ax=plt.subplots(1,1,figsize=(11,3))
#fig.title('Mesozooplankton Biomass')
levels = np.arange(0, 35, .1)


cb=visualisations.contour_thalweg(ax,f12.variables['nitrate'][il,...],fbathy,fmesh,clevels=levels,cmap=cmocean.cm.deep)
cb.set_label('$\mu$M', rotation=90,labelpad=6)
ax.set_ylim(430,0)


fig.suptitle('December 2015 Nitrate', fontsize=16)
#ax.text(15, 100, '(d)', fontsize=15,  color='k')

plt.savefig('Nitrate201512.png', bbox_inches='tight',dpi=1000,transparent=False)

# %%
f1.close()

# %%
f2.close()

# %%
f3.close()

# %%
f4.close()

# %%
f5.close()

# %%
f6.close()

# %%
f7.close()

# %%
f8.close()

# %%
f9.close()

# %%
f10.close()

# %%
f11.close()

# %%
f12.close()

# %%
clim.close()
