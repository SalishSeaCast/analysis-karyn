# %%
import xarray as xr
import numpy as np
from datetime import datetime
from calendar import monthrange
from matplotlib import pyplot as plt, colors
from windrose import WindroseAxes
from cmocean import cm as cmo
from tqdm.notebook import tqdm
from salishsea_tools import wind_tools, places, viz_tools

# %matplotlib inline

# %%
plt.rcParams['font.size'] = 14

# %%
# Define timerange
timerange1 = [datetime(2007, 3, 1), datetime(2008, 5, 31)]

# %%
def plot_timeseries(station, time_obs, wspd_obs, wdir_obs):
    """Plot timeseries
    """
    
    # Plot timeseries
    fig, axs = plt.subplots(2, 1, figsize=(17, 6))
    for ax in axs:
        #ax.set_xlim([time_HRDPS[0], time_HRDPS[-1]])

    # Upper panel: wind speed
        axs[0].plot(time_obs, wspd_obs, 'k-',label='Wind Speed')
        axs[0].set_ylim([0, 17])
        axs[0].set_ylabel('speed [m/s]')
        axs[0].xaxis.set_ticklabels('')

    # Lower panel: wind direction
        axs[1].plot(time_obs, wdir_obs, 'r-',label='Wind Direction')
        axs[1].set_ylim([0, 360])
        axs[1].set_ylabel('dir [$^{\circ}$CCW from E]')
        
    
    return fig, axs

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange1]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2007',fontsize=24)
# Out:
# Text(0.5, 0.98, '2007')

# %%
# Define timerange
timerange2 = [datetime(2008, 3, 1), datetime(2008, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange2]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2008',fontsize=24)
# Out:
# Text(0.5, 0.98, '2008')

# %%
# Define timerange
timerange3 = [datetime(2009, 3, 1), datetime(2009, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange3]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2009',fontsize=24)
# Out:
# Text(0.5, 0.98, '2009')

# %%
# Define timerange
timerange4 = [datetime(2010, 3, 1), datetime(2010, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange4]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2010',fontsize=24)
# Out:
# Text(0.5, 0.98, '2010')

# %%
# Define timerange
timerange5 = [datetime(2011, 3, 1), datetime(2011, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange5]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2011',fontsize=24)
# Out:
# Text(0.5, 0.98, '2011')

# %%
# Define timerange
timerange6 = [datetime(2012, 3, 1), datetime(2012, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange6]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2012',fontsize=24)
# Out:
# Text(0.5, 0.98, '2012')

# %%
# Define timerange
timerange7 = [datetime(2013, 3, 1), datetime(2013, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange7]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2013',fontsize=24)
# Out:
# Text(0.5, 0.98, '2013')

# %%
# Define timerange
timerange8 = [datetime(2014, 3, 1), datetime(2014, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange8]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2014',fontsize=24)
# Out:
# Text(0.5, 0.98, '2014')

# %%
# Define timerange
timerange9 = [datetime(2015, 3, 1), datetime(2015, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange9]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2015',fontsize=24)
# Out:
# Text(0.5, 0.98, '2015')

# %%
# Define timerange
timerange10 = [datetime(2016, 3, 1), datetime(2016, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange10]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2016',fontsize=24)
# Out:
# Text(0.5, 0.98, '2016')

# %%
# Define timerange
timerange11 = [datetime(2017, 3, 1), datetime(2017, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange11]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2017',fontsize=24)
# Out:
# Text(0.5, 0.98, '2017')

# %%
# Define timerange
timerange12 = [datetime(2018, 3, 1), datetime(2018, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange12]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2018',fontsize=24)
# Out:
# Text(0.5, 0.98, '2018')

# %%
# Define timerange
timerange13 = [datetime(2019, 3, 1), datetime(2019, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange13]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2019',fontsize=24)
# Out:
# Text(0.5, 0.98, '2019')

# %%
# Define timerange
timerange14 = [datetime(2020, 3, 1), datetime(2020, 3, 31)]

# %%
# Specify station and time range
station = 'Sand Heads'

# Get EC station observations
# Must be within a single calendar month. Date string format is specific.
start, end = [t.strftime('%d-%b-%Y') for t in timerange14]
wspd_obs, wdir_obs, temp, time_obs, lat, lon = wind_tools.get_EC_observations(station, start, end)



# Plot time series
fig, axs = plot_timeseries(station, time_obs, wspd_obs,wdir_obs)
fig.suptitle('2020',fontsize=24)
# Out:
# Text(0.5, 0.98, '2020')

# %%
# Make figure
fig = plt.figure(figsize=(12, 6))

# Loop through obs
for wspd, wdir, title, xpos in zip([wspd_obs],[wdir_obs], ['obs'], [0, 0.5]):

    # Make windrose object
    ax = WindroseAxes.from_ax(fig=fig)
    ax.set_position([xpos, 0.15, 0.4, 0.8])

    # Translate angle to CW from N
    angle = 270 - wdir
    angle[angle < 0] = angle[angle < 0] + 360
    
    # Plot windrose
    ax.bar(angle, wspd, bins=range(0, 11, 2), nsector=20, normed=True, opening=0.8, edgecolor='k', cmap=cmo.speed)

    # Formatting
    ax.set_ylim([0, 20])
    ax.yaxis.set_ticks([5, 10, 15, 20])
    ax.yaxis.set_ticklabels('')
    ax.xaxis.set_ticklabels('')
    ax.xaxis.set_ticklabels(['E', 'NE', 'N', 'NW', 'W', 'SW', 'S', 'SE'])
    ax.yaxis.set_ticklabels([f'{tick}%' for tick in [5, 10, 15, 20]])
    ax.set_title(title)
    
    # Manually get legend handles (since WindroseAxes.bar returns None)
    handles = ax.get_children()[:6]

# Add legend
labels = ['0-2', '2-4', '4-6', '6-8', '8-10', '> 10']
fig.legend(frameon=False, handles=handles, labels=labels, bbox_to_anchor=(1.05, 0.45), title='m/s')

plt.show()
