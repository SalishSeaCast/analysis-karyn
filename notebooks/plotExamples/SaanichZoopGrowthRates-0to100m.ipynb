# %%
import netCDF4 as nc
import datetime as dt
import pandas as pd
import subprocess
import requests
import matplotlib.pyplot as plt
import cmocean
import numpy as np
import os
import glob
import dateutil as dutil
from salishsea_tools import viz_tools, places
import xarray as xr
from salishsea_tools import evaltools as et

# %matplotlib inline

# %% [raw]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %% [markdown]
# Determine model grid points using lat/log

# %%
jjii = xr.open_dataset('/data/sallen/MEOPAR/grid/grid_from_lat_lon_mask999.nc')

# %%
#Find model grid location for Saanich Inlet
lat, lon = 48.59, -123.51 #Saanich Sampling Station
method = 'nearest'
jj = jjii.jj.sel(lats=lat, lons=lon, method=method).item()
ii = jjii.ii.sel(lats=lat, lons=lon, method=method).item()
print (ii, jj)
# Out:
# 198 343

# %%
jjii.close()

# %%
jS3,iS3=places.PLACES['S3']['NEMO grid ji']

# %%
places.PLACES['Juan de Fuca Strait']
# Out:
# {'lon lat': (-124.7, 48.47)}

# %%
jJF,iJF=[290,130]

# %%
places.PLACES['Puget Sound']
# Out:
# {'lon lat': (-122.67, 48)}

# %%
jPS,iPS=[107,254]

# %%
jBS, iBS=places.PLACES['Baynes Sound']['NEMO grid ji']

# %%
jGI,iGI=[390,240]

# %%
jNSoG,iNSoG=[638,197]

# %%
jSI,iSI=[343,198]

# %%
df=pd.read_excel('/ocean/ksuchy/MOAD/observe/SaanichGrowthRates.xlsx',engine='openpyxl')

# %%
df
# Out:
#         dtUTC    Lat     Lon  Z_lower  Z_upper   P/B  \
# 0  2010-03-11  48.59 -123.51      100        0  0.07
# 1  2010-03-18  48.59 -123.51      100        0  0.03
# 2  2010-03-25  48.59 -123.51      100        0  0.19
# 3  2010-04-01  48.59 -123.51      100        0  0.12
# 4  2010-04-08  48.59 -123.51      100        0  0.09
# 5  2010-04-22  48.59 -123.51      100        0  0.17
# 6  2010-04-30  48.59 -123.51      100        0  0.33
# 7  2010-05-10  48.59 -123.51      100        0  0.01
# 8  2010-05-17  48.59 -123.51      100        0  0.04
# 9  2010-06-02  48.59 -123.51      100        0  0.42
# 10 2010-06-14  48.59 -123.51      100        0  0.04
# 11 2010-06-28  48.59 -123.51      100        0  0.17
# 12 2010-07-15  48.59 -123.51      100        0  0.08
# 13 2010-07-27  48.59 -123.51      100        0  0.03
# 14 2010-08-12  48.59 -123.51      100        0  0.13
# 15 2011-03-24  48.59 -123.51      100        0  0.04
# 16 2011-04-06  48.59 -123.51      100        0  0.05
# 17 2011-04-20  48.59 -123.51      100        0  0.10
# 18 2011-05-05  48.59 -123.51      100        0  0.22
# 19 2011-05-19  48.59 -123.51      100        0  0.15
# 20 2011-06-06  48.59 -123.51      100        0  0.05
# 21 2011-06-20  48.59 -123.51      100        0  0.04
# 22 2011-07-05  48.59 -123.51      100        0  0.07
# 23 2011-07-19  48.59 -123.51      100        0  0.04
# 24 2011-08-03  48.59 -123.51      100        0  0.06
# 25 2011-08-17  48.59 -123.51      100        0  0.13
#
#     Production (mg C m-3 d-1)  Total Zoop Biomass  Crustacean Biomass  \
# 0                      1.2440            8.290669            3.243590
# 1                      0.2210            4.060603            2.512094
# 2                      4.2510           36.644737           30.733623
# 3                      1.2260           46.617782           40.007711
# 4                      1.3880           34.579127           25.701994
# 5                      9.9750          262.540128          131.746410
# 6                     15.6050           51.105538           44.424950
# 7                      0.0500           95.222814           77.358661
# 8                      0.0500         3588.541938         3365.892137
# 9                     11.7550         1165.543557          930.559191
# 10                     2.5410         1396.226766         1228.396040
# 11                     8.0670          890.693829          609.192692
# 12                     2.8310         1616.386643          660.058299
# 13                     6.2150          640.733003          569.493513
# 14                     6.6970          235.812269          119.369747
# 15                     3.3780           37.002474           22.026039
# 16                     0.9556           41.704221           28.822037
# 17                     3.3795          547.970909          519.483525
# 18                    12.9355          636.313107          588.587307
# 19                     9.0019         5483.723304         5400.785925
# 20                     0.6042          390.435725          114.105456
# 21                     2.5912          581.781236          441.286398
# 22                     3.9127          197.078307           57.926896
# 23                     2.3874           72.552822           41.045311
# 24                     4.3517          431.966964          355.241949
# 25                     6.8185           90.346259           72.026937
#
#     Non Crustacean Biomass  Copepod Biomass
# 0                 5.047079         0.520046
# 1                 1.548508         0.264141
# 2                 5.911114        23.101529
# 3                 6.610072        19.809854
# 4                 8.877132        12.247770
# 5               130.793718        82.864384
# 6                 6.680588        23.486172
# 7                17.864153        47.502435
# 8               222.649801       369.704100
# 9               234.984366       121.311437
# 10              167.830726        29.656339
# 11              281.501137        26.776027
# 12              956.328345       361.268546
# 13               71.239490       241.090916
# 14              116.442522       101.912763
# 15               14.976435        14.933908
# 16               12.882184         8.616386
# 17               28.487384         8.535709
# 18               47.725800        80.277207
# 19               82.937379        97.278857
# 20              276.330269        12.446180
# 21              140.494838        28.306160
# 22              139.151411        27.702688
# 23               31.507511        15.441573
# 24               76.725016        42.253179
# 25               18.319322        15.997463

# %%
with nc.Dataset('/ocean/eolson/MEOPAR/NEMO-forcing/grid/mesh_mask201702_noLPE.nc') as fm:
    tmask=np.copy(fm.variables['tmask'])
    umask=np.copy(fm.variables['umask'])
    vmask=np.copy(fm.variables['vmask'])
    navlon=np.copy(fm.variables['nav_lon'])
    navlat=np.copy(fm.variables['nav_lat'])
    dept=np.copy(fm.variables['gdept_1d'])
    e3t_0=np.copy(fm.variables['e3t_0'])
    e3u_0=np.copy(fm.variables['e3u_0'])
    e3v_0=np.copy(fm.variables['e3v_0'])
    e1t=np.copy(fm.variables['e1t'])
    e2t=np.copy(fm.variables['e2t'])
    e1v=np.copy(fm.variables['e1v'])
    e2u=np.copy(fm.variables['e2u'])
    A=fm.variables['e1t'][0,:,:]*fm.variables['e2t'][0,:,:]*tmask[0,0,:,:]

# %% [markdown]
# ### Saanich Sampling Location & S3 for Comparison

# %%
fig,ax=plt.subplots(1,1,figsize=(4,6))
ax.pcolormesh(tmask[0,0,:,:])
#ax.plot(130,290,'r*')
ax.plot(iS3,jS3,'r*')
#ax.plot(254,107,'r*')
#ax.plot(iBS,jBS,'r*')
#ax.plot(iGI,jGI,'r*')
#ax.plot(iNSoG,jNSoG,'r*')
ax.plot(iSI,jSI,'r*')
ax.set_aspect(1)

# %%
jpk100=0
for i in range(0,40): #stays same b/c grid cells or write len(dept[0]) instead of 40
    if dept[0][i]<=100:#change this to get diff depths in water column
        jpk100=i
print(jpk100)
jpk100=jpk100+1
print(jpk100)
# Out:
# 26
# 27

# %%
koff=jpk100 # first index of depth > 100

# %%
t0=dt.datetime(2010,1,1) # 1st start date of run
#te=dt.datetime(2011,12,1)# last start date of runfnum=18
stm=np.shape(tmask)
#nlen=36*2
nlen=730
dlist=[t0+dt.timedelta(days=ii) for ii in range(0,nlen)]

# %%
#sdir0='/results/SalishSea/nowcast-green/'
#sdir1='/results/SalishSea/hindcast/'
#sdir3='/data/eolson/MEOPAR/SS36runs/CedarRuns/spring2015_HCMZ/'
#sdir1='/results2/SalishSea/nowcast-green.201905/'
sdir1='/results2/SalishSea/nowcast-green.201905/'

# %%
tmaskC=np.copy(tmask)
tmaskC[:,koff:,:,:]=0
#tmaskC[:,:,370:490,:12]=0
#tmaskC[:,:,887:,30:70]=0

# %%
#f=nc.Dataset('/data/sallen/results/MEOPAR/averages/SalishSea_apr_climate_2007_2019_dia2_T.nc')

# %%
#print(f.variables.keys())

# %%
tlist=dlist
idir=sdir1
fformat1='%d%b%y/'
fformatT='SalishSea_1d_%Y%m%d_%Y%m%d_dia2_T.nc'
fformatP='SalishSea_1h_%Y%m%d_%Y%m%d_carp_T.nc'
meanMESZD100=np.zeros((len(tlist),))
meanMESZD100S3=np.zeros((len(tlist),))
meanMESZD100SI=np.zeros((len(tlist),))

ind=-1
for idt0 in tlist:
    ind=ind+1
    cdir=idt0.strftime(fformat1).lower()
    iffT=idt0.strftime(fformatT)
    iffP=idt0.strftime(fformatP)
    sffT=idir+cdir+iffT
    sffP=idir+cdir+iffP
    f=nc.Dataset(glob.glob(sffT)[0])
    if ind%15==0: print(sffT) 
    fP=nc.Dataset(glob.glob(sffP)[0])
    #e3t=fP.variables['e3t'][:2,:,:,:]
    Vol=A*e3t_0 #m3
    meanMESZD100[ind]=np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:]*f.variables['GRMESZDIAT'][0,:,:,:])/\
            np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:])#mmol/m3 s-1
    meanMESZD100S3[ind]=np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3]*f.variables['GRMESZDIAT'][0,:,jS3,iS3])/\
            np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3])#mmol/m3 s-1
    meanMESZD100SI[ind]=np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI]*f.variables['GRMESZDIAT'][0,:,jSI,iSI])/\
            np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI])#mmol/m3 s-1
    
    
   
    f.close()
    fP.close()
# Out:
# /results2/SalishSea/nowcast-green.201905/01jan10/SalishSea_1d_20100101_20100101_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905
dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23sep11/SalishSea_1d_20110923_20110923_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/08oct11/SalishSea_1d_20111008_20111008_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23oct11/SalishSea_1d_20111023_20111023_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07nov11/SalishSea_1d_20111107_20111107_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22nov11/SalishSea_1d_20111122_20111122_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07dec11/SalishSea_1d_20111207_20111207_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22dec11/SalishSea_1d_20111222_20111222_dia2_T.nc

# %%
tlist=dlist
idir=sdir1
fformat1='%d%b%y/'
fformatT='SalishSea_1d_%Y%m%d_%Y%m%d_dia2_T.nc'
fformatP='SalishSea_1h_%Y%m%d_%Y%m%d_carp_T.nc'
meanMESZM100=np.zeros((len(tlist),))
meanMESZM100S3=np.zeros((len(tlist),))
meanMESZM100SI=np.zeros((len(tlist),))



ind=-1
for idt0 in tlist:
    ind=ind+1
    cdir=idt0.strftime(fformat1).lower()
    iffT=idt0.strftime(fformatT)
    iffP=idt0.strftime(fformatP)
    sffT=idir+cdir+iffT
    sffP=idir+cdir+iffP
    f=nc.Dataset(glob.glob(sffT)[0])
    if ind%15==0: print(sffT) 
    fP=nc.Dataset(glob.glob(sffP)[0])
    #e3t=fP.variables['e3t'][:2,:,:,:]
    Vol=A*e3t_0

    meanMESZM100[ind]=np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:]*f.variables['GRMESZMICZ'][0,:,:,:])/\
            np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:])#mmol/m3 s-1
    meanMESZM100S3[ind]=np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3]*f.variables['GRMESZMICZ'][0,:,jS3,iS3])/\
            np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3])#mmol/m3 s-1
    meanMESZM100SI[ind]=np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI]*f.variables['GRMESZMICZ'][0,:,jSI,iSI])/\
            np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI])#mmol/m3 s-1
    
    
    f.close()
    fP.close()
# Out:
# /results2/SalishSea/nowcast-green.201905/01jan10/SalishSea_1d_20100101_20100101_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/16jan10/SalishSea_1d_20100116_20100116_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/31jan10/SalishSea_1d_20100131_20100131_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/15feb10/SalishSea_1d_20100215_20100215_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/02mar10/SalishSea_1d_20100302_20100302_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/17mar10/SalishSea_1d_20100317_20100317_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/01apr10/SalishSea_1d_20100401_20100401_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/16apr10/SalishSea_1d_20100416_20100416_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/01may10/SalishSea_1d_20100501_20100501_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/16may10/SalishSea_1d_20100516_20100516_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/31may10/SalishSea_1d_20100531_20100531_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/15jun10/SalishSea_1d_20100615_20100615_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/30jun10/SalishSea_1d_20100630_20100630_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/15jul10/SalishSea_1d_20100715_20100715_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/30jul10/SalishSea_1d_20100730_20100730_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/14aug10/SalishSea_1d_20100814_20100814_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/29aug10/SalishSea_1d_20100829_20100829_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/13sep10/SalishSea_1d_20100913_20100913_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/28sep10/SalishSea_1d_20100928_20100928_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/13oct10/SalishSea_1d_20101013_20101013_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/28oct10/SalishSea_1d_20101028_20101028_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/12nov10/SalishSea_1d_20101112_20101112_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/27nov10/SalishSea_1d_20101127_20101127_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/12dec10/SalishSea_1d_20101212_20101212_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/27dec10/SalishSea_1d_20101227_20101227_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/11jan11/SalishSea_1d_20110111_20110111_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/26jan11/SalishSea_1d_20110126_20110126_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/10feb11/SalishSea_1d_20110210_20110210_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/25feb11/SalishSea_1d_20110225_20110225_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/12mar11/SalishSea_1d_20110312_20110312_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/27mar11/SalishSea_1d_20110327_20110327_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/11apr11/SalishSea_1d_20110411_20110411_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/26apr11/SalishSea_1d_20110426_20110426_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/11may11/SalishSea_1d_20110511_20110511_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/26may11/SalishSea_1d_20110526_20110526_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/10jun11/SalishSea_1d_20110610_20110610_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/25jun11/SalishSea_1d_20110625_20110625_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/10jul11/SalishSea_1d_20110710_20110710_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/25jul11/SalishSea_1d_20110725_20110725_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/09aug11/SalishSea_1d_20110809_20110809_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/24aug11/SalishSea_1d_20110824_20110824_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/08sep11/SalishSea_1d_20110908_20110908_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23sep11/SalishSea_1d_20110923_20110923_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/08oct11/SalishSea_1d_20111008_20111008_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23oct11/SalishSea_1d_20111023_20111023_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07nov11/SalishSea_1d_20111107_20111107_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22nov11/SalishSea_1d_20111122_20111122_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07dec11/SalishSea_1d_20111207_20111207_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22dec11/SalishSea_1d_20111222_20111222_dia2_T.nc

# %%
tlist=dlist
idir=sdir1
fformat1='%d%b%y/'
fformatT='SalishSea_1d_%Y%m%d_%Y%m%d_dia2_T.nc'
fformatP='SalishSea_1h_%Y%m%d_%Y%m%d_carp_T.nc'
meanMESZC100=np.zeros((len(tlist),))
meanMESZC100S3=np.zeros((len(tlist),))
meanMESZC100SI=np.zeros((len(tlist),))



ind=-1
for idt0 in tlist:
    ind=ind+1
    cdir=idt0.strftime(fformat1).lower()
    iffT=idt0.strftime(fformatT)
    iffP=idt0.strftime(fformatP)
    sffT=idir+cdir+iffT
    sffP=idir+cdir+iffP
    f=nc.Dataset(glob.glob(sffT)[0])
    if ind%15==0: print(sffT) 
    fP=nc.Dataset(glob.glob(sffP)[0])
    #e3t=fP.variables['e3t'][:2,:,:,:]
    Vol=A*e3t_0
  
    meanMESZC100[ind]=np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:]*f.variables['GRMESZMRUB'][0,:,:,:])/\
            np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:])#mmol/m3 s-1
    meanMESZC100S3[ind]=np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3]*f.variables['GRMESZMRUB'][0,:,jS3,iS3])/\
            np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3])#mmol/m3 s-1
    meanMESZC100SI[ind]=np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI]*f.variables['GRMESZMRUB'][0,:,jSI,iSI])/\
            np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI])#mmol/m3 s-1
    
   
    
    f.close()
    fP.close()
# Out:
# /results2/SalishSea/nowcast-green.201905/01jan10/SalishSea_1d_20100101_20100101_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905
dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/24aug11/SalishSea_1d_20110824_20110824_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/08sep11/SalishSea_1d_20110908_20110908_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23sep11/SalishSea_1d_20110923_20110923_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/08oct11/SalishSea_1d_20111008_20111008_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/23oct11/SalishSea_1d_20111023_20111023_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07nov11/SalishSea_1d_20111107_20111107_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22nov11/SalishSea_1d_20111122_20111122_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/07dec11/SalishSea_1d_20111207_20111207_dia2_T.nc
# /results2/SalishSea/nowcast-green.201905/22dec11/SalishSea_1d_20111222_20111222_dia2_T.nc

# %%
tlist=dlist
idir=sdir1
fformat1='%d%b%y/'
fformatZ='SalishSea_1d_%Y%m%d_%Y%m%d_ptrc_T.nc' #change to ptrc file to get zoop biomass
fformatP='SalishSea_1h_%Y%m%d_%Y%m%d_carp_T.nc'
meanMESZoop100=np.zeros((len(tlist),))
meanMESZoop100S3=np.zeros((len(tlist),))
meanMESZoop100SI=np.zeros((len(tlist),))

ind=-1
for idt0 in tlist:
    ind=ind+1
    cdir=idt0.strftime(fformat1).lower()
    iffZ=idt0.strftime(fformatZ)
    iffP=idt0.strftime(fformatP)
    sffZ=idir+cdir+iffZ
    sffP=idir+cdir+iffP
    f=nc.Dataset(glob.glob(sffZ)[0])
    if ind%15==0: print(sffZ) 
    fP=nc.Dataset(glob.glob(sffP)[0])
    #e3t=fP.variables['e3t'][:2,:,:,:]
    Vol=A*e3t_0 #m3
    meanMESZoop100[ind]=np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:]*f.variables['mesozooplankton'][0,:,:,:])/\
            np.sum(tmaskC[0,:,:,:]*Vol[0,:,:,:])#mmol/m3 s-1
    meanMESZoop100S3[ind]=np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3]*f.variables['mesozooplankton'][0,:,jS3,iS3])/\
            np.sum(tmaskC[0,:,jS3,iS3]*Vol[0,:,jS3,iS3])#mmol/m3 s-1
    meanMESZoop100SI[ind]=np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI]*f.variables['mesozooplankton'][0,:,jSI,iSI])/\
            np.sum(tmaskC[0,:,jSI,iSI]*Vol[0,:,jSI,iSI])#mmol/m3 s-1
    
    
   
    f.close()
    fP.close()
# Out:
# /results2/SalishSea/nowcast-green.201905/01jan10/SalishSea_1d_20100101_20100101_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/16jan10/SalishSea_1d_20100116_20100116_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/31jan10/SalishSea_1d_20100131_20100131_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/15feb10/SalishSea_1d_20100215_20100215_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/02mar10/SalishSea_1d_20100302_20100302_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/17mar10/SalishSea_1d_20100317_20100317_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/01apr10/SalishSea_1d_20100401_20100401_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/16apr10/SalishSea_1d_20100416_20100416_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/01may10/SalishSea_1d_20100501_20100501_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/16may10/SalishSea_1d_20100516_20100516_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/31may10/SalishSea_1d_20100531_20100531_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/15jun10/SalishSea_1d_20100615_20100615_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/30jun10/SalishSea_1d_20100630_20100630_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/15jul10/SalishSea_1d_20100715_20100715_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/30jul10/SalishSea_1d_20100730_20100730_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/14aug10/SalishSea_1d_20100814_20100814_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/29aug10/SalishSea_1d_20100829_20100829_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/13sep10/SalishSea_1d_20100913_20100913_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/28sep10/SalishSea_1d_20100928_20100928_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/13oct10/SalishSea_1d_20101013_20101013_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/28oct10/SalishSea_1d_20101028_20101028_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/12nov10/SalishSea_1d_20101112_20101112_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/27nov10/SalishSea_1d_20101127_20101127_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/12dec10/SalishSea_1d_20101212_20101212_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/27dec10/SalishSea_1d_20101227_20101227_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/11jan11/SalishSea_1d_20110111_20110111_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/26jan11/SalishSea_1d_20110126_20110126_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/10feb11/SalishSea_1d_20110210_20110210_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/25feb11/SalishSea_1d_20110225_20110225_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/12mar11/SalishSea_1d_20110312_20110312_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/27mar11/SalishSea_1d_20110327_20110327_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/11apr11/SalishSea_1d_20110411_20110411_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/26apr11/SalishSea_1d_20110426_20110426_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/11may11/SalishSea_1d_20110511_20110511_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/26may11/SalishSea_1d_20110526_20110526_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/10jun11/SalishSea_1d_20110610_20110610_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/25jun11/SalishSea_1d_20110625_20110625_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/10jul11/SalishSea_1d_20110710_20110710_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/25jul11/SalishSea_1d_20110725_20110725_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/09aug11/SalishSea_1d_20110809_20110809_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/24aug11/SalishSea_1d_20110824_20110824_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/08sep11/SalishSea_1d_20110908_20110908_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/23sep11/SalishSea_1d_20110923_20110923_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/08oct11/SalishSea_1d_20111008_20111008_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/23oct11/SalishSea_1d_20111023_20111023_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/07nov11/SalishSea_1d_20111107_20111107_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/22nov11/SalishSea_1d_20111122_20111122_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/07dec11/SalishSea_1d_20111207_20111207_ptrc_T.nc
# /results2/SalishSea/nowcast-green.201905/22dec11/SalishSea_1d_20111222_20111222_ptrc_T.nc

# %%
meanMESZtotal100=meanMESZD100+meanMESZF100+meanMESZC100+meanMESZM100+meanMESZP100
meanMESZtotal100SI=meanMESZD100SI+meanMESZF100SI+meanMESZC100SI+meanMESZM100SI+meanMESZP100SI
meanMESZtotal100S3=meanMESZD100S3+meanMESZF100S3+meanMESZC100S3+meanMESZM100S3+meanMESZP100S3

# %%
meanGR100=meanMESZtotal100*0.3/meanMESZoop100
meanGR100SI=meanMESZtotal100SI*0.3/meanMESZoop100SI
meanGR100S3=meanMESZtotal100S3*0.3/meanMESZoop100S3

# %%
fig,ax=plt.subplots(1,1,figsize=(12,5))
ax.plot(tlist,(meanGR100*86400),'k-',label='Model Domain',linewidth=2.5) #multiply by 86400 to get d-1
ax.plot(tlist,(meanGR100SI*86400),':',color='blue',label='Saanich Inlet') #multiply by 5.7 and 12 to convert to mg C m-3
ax.plot(tlist,(meanGR100S3*86400),':',color='darkgreen',label='S3')
ax.plot(df['dtUTC'],df['P/B'],'.',color='red',label='Daily P/B')
ax.legend(frameon=False)
ax.set_ylim((0,.5))
ax.set_ylabel('Growth Rate (d-1)')
ax.set_title('Average Mesozooplankton Growth Rates (upper 100m)')
# Out:
# Text(0.5, 1.0, 'Average Mesozooplankton Growth Rates (upper 100m)')

# %% [markdown]
# Import model data for comparison with observations

# %%
start_date = dt.datetime(2010,1,1)
end_date = dt.datetime(2011,12,31)
flen=1 # number of days per model output file. always 1 for 201905 and 201812 model runs
namfmt='nowcast' # for 201905 and 201812 model runs, this should always be 'nowcast'
# filemap is dictionary of the form variableName: fileType, where variableName is the name
# of the variable you want to extract and fileType designates the type of 
# model output file it can be found in (usually ptrc_T for biology, grid_T for temperature and 
# salinity)
filemap={'GRMESZDIAT':'dia2_T','GRMESZPHY':'dia2_T','GRMESZMICZ':'dia2_T','GRMESZMRUB':'dia2_T',\
         'GRMESZPON':'dia2_T','mesozooplankton':'ptrc_T'}

# fdict is a dictionary mappy file type to its time resolution. Here, 1 means hourly output
# (1h file) and 24 means daily output (1d file). In certain runs, multiple time resolutions 
# are available
fdict={'dia2_T':24,'grid_T':1,'ptrc_T':1}#24 for hours averaged

# %%
PATH= '/results2/SalishSea/nowcast-green.201905/'

# %%
df2=pd.read_excel('/ocean/ksuchy/MOAD/observe/SaanichGrowthRatesbyDepth.xlsx',engine='openpyxl')

# %%
data=et.matchData(df2,filemap,fdict,start_date,end_date,namfmt,PATH,flen,quiet=False,method='vertNet');
# Out:
# ftype=dia2_T, are you sure? (if yes, add to list)

# %%
data
# Out:
#          dtUTC    Lat     Lon  Z_lower  Z_upper       P/B  \
# 0   2010-03-11  48.59 -123.51        5        0  0.044129
# 1   2010-03-11  48.59 -123.51       25        0  0.158474
# 2   2010-03-11  48.59 -123.51       50        0  0.006078
# 3   2010-03-11  48.59 -123.51       75        0  0.070781
# 4   2010-03-18  48.59 -123.51        5        0  0.037767
# ..         ...    ...     ...      ...      ...       ...
# 128 2011-08-17  48.59 -123.51       25        0  0.080900
# 129 2011-08-17  48.59 -123.51       75        0  0.076869
# 130 2011-08-17  48.59 -123.51        5        0  0.377273
# 131 2011-08-17  48.59 -123.51       15        0  0.083013
# 132 2011-08-17  48.59 -123.51      100        0  0.076833
#
#      Productivity (mg C m-3 d-1)    j    i  mod_GRMESZDIAT  mod_GRMESZPHY  \
# 0                       1.750165  343  198    1.015344e-07   3.965160e-07
# 1                       5.320303  343  198    4.740443e-08   2.530406e-07
# 2                       0.187449  343  198    2.467757e-08   1.547190e-07
# 3                       1.998146  343  198    1.444392e-08   9.194011e-08
# 4                       0.946501  343  198    3.176289e-07   3.958652e-07
# ..                           ...  ...  ...             ...            ...
# 128                     1.450128  343  198    6.491772e-07   2.100237e-06
# 129                     2.028692  343  198    2.002612e-07   6.358059e-07
# 130                     7.411175  343  198    8.794318e-07   7.480325e-06
# 131                     1.820181  343  198    9.948599e-07   3.443430e-06
# 132                     2.024897  343  198    1.588620e-07   5.039276e-07
#
#      mod_GRMESZMICZ  mod_GRMESZMRUB  mod_GRMESZPON  mod_mesozooplankton  \
# 0      6.095678e-08    2.827948e-07   5.396732e-08             0.713384
# 1      1.759674e-08    1.363575e-07   8.768528e-08             0.587618
# 2      8.961642e-09    7.186004e-08   6.977479e-08             0.451125
# 3      5.240036e-09    4.201788e-08   4.289083e-08             0.318837
# 4      1.099075e-07    3.991029e-07   4.529318e-08             0.694093
# ..              ...             ...            ...                  ...
# 128    1.120745e-06    4.468670e-07   9.109389e-07             0.899951
# 129    3.417488e-07    1.331214e-07   6.001178e-07             0.517740
# 130    3.059509e-06    1.106712e-06   9.082496e-07             1.682257
# 131    1.737285e-06    6.997294e-07   9.976845e-07             1.146890
# 132    2.706539e-07    1.054278e-07   5.205587e-07             0.458520
#
#      k_upper  k_lower
# 0          0        4
# 1          0       20
# 2          0       23
# 3          0       25
# 4          0        4
# ..       ...      ...
# 128        0       20
# 129        0       25
# 130        0        4
# 131        0       14
# 132        0       26
#
# [133 rows x 17 columns]

# %%
cm1=cmocean.cm.thermal
with nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/bathymetry_201702.nc') as bathy:
    bathylon=np.copy(bathy.variables['nav_lon'][:,:])
    bathylat=np.copy(bathy.variables['nav_lat'][:,:])
    bathyZ=np.copy(bathy.variables['Bathymetry'][:,:])

# %%
data.keys()
# Out:
# Index(['dtUTC', 'Lat', 'Lon', 'Z_lower', 'Z_upper', 'P/B',
#        'Productivity (mg C m-3 d-1)', 'j', 'i', 'mod_GRMESZDIAT',
#        'mod_GRMESZPHY', 'mod_GRMESZMICZ', 'mod_GRMESZMRUB', 'mod_GRMESZPON',
#        'mod_mesozooplankton', 'k_upper', 'k_lower'],
#       dtype='object')

# %%
data['mod_prod']=(data['mod_GRMESZDIAT']+data['mod_GRMESZPHY']+data['mod_GRMESZMICZ']+data['mod_GRMESZMRUB']+data['mod_GRMESZPON'])

# %%
data['mod_growth']=data['mod_prod']*0.3/data['mod_mesozooplankton']*86400

# %%
data
# Out:
#          dtUTC    Lat     Lon  Z_lower  Z_upper       P/B  \
# 0   2010-03-11  48.59 -123.51        5        0  0.044129
# 1   2010-03-11  48.59 -123.51       25        0  0.158474
# 2   2010-03-11  48.59 -123.51       50        0  0.006078
# 3   2010-03-11  48.59 -123.51       75        0  0.070781
# 4   2010-03-18  48.59 -123.51        5        0  0.037767
# ..         ...    ...     ...      ...      ...       ...
# 128 2011-08-17  48.59 -123.51       25        0  0.080900
# 129 2011-08-17  48.59 -123.51       75        0  0.076869
# 130 2011-08-17  48.59 -123.51        5        0  0.377273
# 131 2011-08-17  48.59 -123.51       15        0  0.083013
# 132 2011-08-17  48.59 -123.51      100        0  0.076833
#
#      Productivity (mg C m-3 d-1)    j    i  mod_GRMESZDIAT  mod_GRMESZPHY  \
# 0                       1.750165  343  198    1.015344e-07   3.965160e-07
# 1                       5.320303  343  198    4.740443e-08   2.530406e-07
# 2                       0.187449  343  198    2.467757e-08   1.547190e-07
# 3                       1.998146  343  198    1.444392e-08   9.194011e-08
# 4                       0.946501  343  198    3.176289e-07   3.958652e-07
# ..                           ...  ...  ...             ...            ...
# 128                     1.450128  343  198    6.491772e-07   2.100237e-06
# 129                     2.028692  343  198    2.002612e-07   6.358059e-07
# 130                     7.411175  343  198    8.794318e-07   7.480325e-06
# 131                     1.820181  343  198    9.948599e-07   3.443430e-06
# 132                     2.024897  343  198    1.588620e-07   5.039276e-07
#
#      mod_GRMESZMICZ  mod_GRMESZMRUB  mod_GRMESZPON  mod_mesozooplankton  \
# 0      6.095678e-08    2.827948e-07   5.396732e-08             0.713384
# 1      1.759674e-08    1.363575e-07   8.768528e-08             0.587618
# 2      8.961642e-09    7.186004e-08   6.977479e-08             0.451125
# 3      5.240036e-09    4.201788e-08   4.289083e-08             0.318837
# 4      1.099075e-07    3.991029e-07   4.529318e-08             0.694093
# ..              ...             ...            ...                  ...
# 128    1.120745e-06    4.468670e-07   9.109389e-07             0.899951
# 129    3.417488e-07    1.331214e-07   6.001178e-07             0.517740
# 130    3.059509e-06    1.106712e-06   9.082496e-07             1.682257
# 131    1.737285e-06    6.997294e-07   9.976845e-07             1.146890
# 132    2.706539e-07    1.054278e-07   5.205587e-07             0.458520
#
#      k_upper  k_lower      mod_prod  mod_growth
# 0          0        4  8.957693e-07    0.032547
# 1          0       20  5.420846e-07    0.023912
# 2          0       23  3.299930e-07    0.018960
# 3          0       25  1.965328e-07    0.015977
# 4          0        4  1.267798e-06    0.047344
# ..       ...      ...           ...         ...
# 128        0       20  5.227965e-06    0.150574
# 129        0       25  1.911055e-06    0.095675
# 130        0        4  1.343423e-05    0.206993
# 131        0       14  7.872988e-06    0.177932
# 132        0       26  1.559430e-06    0.088154
#
# [133 rows x 19 columns]

# %%
def byDepth(ax,obsvar,modvar,lims):
    SI=et.varvarPlot(ax,data,obsvar,modvar,'Z_lower',(15,50),'z','m',('orange','darkturquoise','navy'))
    l=ax.legend(handles=SI)
    ax.set_xlabel('Obs')
    ax.set_ylabel('Model')
    ax.plot(lims,lims,'k-',alpha=.5)
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    ax.set_aspect(1)
    return SI,l

# %%
fig,ax=plt.subplots(1,1,figsize=(10,10))
fig.subplots_adjust(hspace=1)
ax.plot(data['P/B'],data['mod_growth'],'k.')
ax.set_title('Mesozooplankton Specific Growth Rate (d-1)')
ax.set_xlabel('Obs')
ax.set_ylabel('Model')
ax.plot((0,40),(0,40),'r-',alpha=.3)
ax.set_xlim(0,1.5)
ax.set_ylim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
obsvar='P/B'
modvar='mod_growth'

fig, ax = plt.subplots(1,1,figsize = (16,7))
SI,l=byDepth(ax,obsvar,modvar,(0,1.5))
ax.set_title('Mesozooplankton Specific Growth Rate (d-1) By Depth')
# Out:
# Text(0.5, 1.0, 'Mesozooplankton Specific Growth Rate (d-1) By Depth')

# %%
# define log transform function with slight shift to accommodate zero values
def logt(x):
    return np.log10(x+.001)

# %%
data['L10P/B']=logt(data['P/B'])
data['L10mod_growth']=logt(data['mod_growth'])

# %% [markdown]
# ### Depth-specific Point by Point comparisions of model vs obs

# %%
obsvar2='L10P/B'
modvar2='L10mod_growth'

fig, ax = plt.subplots(1,1,figsize = (16,7))
SI,l=byDepth(ax,obsvar2,modvar2,(-3,1))
ax.set_title('Mesozooplankton Specific Growth Rate (d-1) By Depth')
# Out:
# Text(0.5, 1.0, 'Mesozooplankton Specific Growth Rate (d-1) By Depth')
