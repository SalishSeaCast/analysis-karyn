# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from salishsea_tools import evaltools as et, viz_tools
import os
import datetime as dt
import gsw
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import matplotlib.dates as mdates
import cmocean as cmo
import scipy.interpolate as sinterp
import cmocean
import json
import f90nml
from collections import OrderedDict

fs=16
mpl.rc('xtick', labelsize=fs)
mpl.rc('ytick', labelsize=fs)
mpl.rc('legend', fontsize=fs)
mpl.rc('axes', titlesize=fs)
mpl.rc('axes', labelsize=fs)
mpl.rc('figure', titlesize=fs)
mpl.rc('font', size=fs)
mpl.rc('font', family='sans-serif', weight='normal', style='normal')

import warnings
#warnings.filterwarnings('ignore')
from IPython.display import Markdown, display

# %matplotlib inline

# %% [markdown]
# ## Import IOS Zooplankton data and create dataframe

# %%
ls '/ocean/ksuchy/MOAD/observe/Data and Code files for KS 2020dec11/2020_05_21 1995-2011 SoG VNH.csv'
# Out:
# /ocean/ksuchy/MOAD/observe/Data and Code files for KS 2020dec11/2020_05_21 1995-2011 SoG VNH.csv

# %%
df=pd.read_csv('/ocean/ksuchy/MOAD/observe/Data and Code files for KS 2020dec11/2020_05_21 2012-2015 SoG VNH.csv',
               encoding = "ISO-8859-1")

# %%
df
# Out:
#                     Key                 region_name Station          PROJECT  \
# 0      IOS2012005000901  Northern Strait of Georgia      22        Str. Geo.
# 1      IOS2012005000901  Northern Strait of Georgia      22        Str. Geo.
# 2      IOS2012005000901  Northern Strait of Georgia      22        Str. Geo.
# 3      IOS2012005000901  Northern Strait of Georgia      22        Str. Geo.
# 4      IOS2012005000901  Northern Strait of Georgia      22        Str. Geo.
# ...                 ...                         ...     ...              ...
# 60225  SOO2015095000801                 Tidal Mixed   MAC41  Citizen Science
# 60226  SOO2015095000801                 Tidal Mixed   MAC41  Citizen Science
# 60227  SOO2015095000801                 Tidal Mixed   MAC41  Citizen Science
# 60228  SOO2015095000801                 Tidal Mixed   MAC41  Citizen Science
# 60229  SOO2015095000801                 Tidal Mixed   MAC41  Citizen Science
#
# ...

# %%
df.keys()
# Out:
# Index(['Key', 'region_name', 'Station', 'PROJECT', 'lon', 'lat', 'Date',
#        'STN_TIME', 'Twilight', 'Net_Type', 'Mesh_Size(um)', 'Net_Mouth_Dia(m)',
#        'DEPTH_STRT1', 'DEPTH_END1', 'Bottom Depth(m)', 'Volume Filtered(m3)',
#        'CTD', 'NOTES', 'PI', 'Phylum:', 'Class:', 'Order:', 'Family:', 'Name',
#        'Abundance(#/m3)', 'Biomass(mg/m3)', 'NumberOfSpecies',
#        'Station Diversity', 'Station Equitability'],
#       dtype='object')

# %%
df['Biomass(mg/m3)']
# Out:
# 0        0.06113
# 1        1.22254
# 2        1.44871
# 3        0.07030
# 4        0.06017
#           ...
# 60225    0.31797
# 60226    0.06319
# 60227    0.01296
# 60228    0.46414
# 60229    0.02808
# Name: Biomass(mg/m3), Length: 60230, dtype: float64

# %% [markdown]
# ### Convert date to proper format

# %%
df['Date'][0],df['STN_TIME'][0]
# Out:
# ('6/14/2012', '7:32')

# %%
df['Date'][1000:1020]
# Out:
# 1000    6/15/2012
# 1001    6/15/2012
# 1002    6/15/2012
# 1003    6/15/2012
# 1004    6/15/2012
# 1005    6/15/2012
# 1006    6/15/2012
# 1007    6/15/2012
# 1008    6/15/2012
# 1009    6/15/2012
# 1010    6/15/2012
# 1011    6/15/2012
# 1012    6/15/2012
# 1013    6/15/2012
# 1014    6/15/2012
# 1015    6/15/2012
# 1016    6/15/2012
# 1017    6/15/2012
# 1018    6/15/2012
# 1019    6/15/2012
# Name: Date, dtype: object

# %%
df['Date'][0].split('/')
# Out:
# ['6', '14', '2012']

# %%
dateslist=list()

# %%
for el in df['Date']:
    dateslist.append(el.split('/'))

# %%
timeslist=list()
for el in df['STN_TIME']:
    timeslist.append(el.split(':'))

# %%
dts=list()
for ii,jj in zip(dateslist,timeslist):
    dts.append(dt.datetime(int(ii[2]),int(ii[0]),int(ii[1]),int(jj[0]),int(jj[1])))

# %%
df.loc[df.Twilight=='Daylight']['STN_TIME'].unique()
# Out:
# array(['7:32', '7:52', '3:30', '7:42', '7:49', '15:09', '16:30', '22:09',
#        '22:27', '19:36', '19:53', '9:21', '9:35', '13:29', '13:45',
#        '19:25', '19:43', '5:26', '5:43', '5:45', '5:47', '5:56', '5:59',
#        '8:38', '8:39', '8:40', '8:41', '8:57', '11:10', '11:44', '11:45',
#        '11:47', '11:48', '11:49', '12:40', '12:42', '15:14', '15:15',
#        '15:16', '15:17', '15:18', '17:54', '17:55', '17:57', '17:58',
#        '17:59', '5:39', '6:05', '14:47', '15:02', '19:13', '19:30',
#        '14:32', '14:49', '20:04', '20:24', '20:27', '20:47', '9:37',
#        '9:48', '13:57', '14:17', '19:41', '19:59', '7:18', '7:53', '9:25',
#        '12:57', '13:09', '7:30', '7:45', '13:33', '13:36', '13:38',
#        '10:00', '10:30', '11:00', '11:30', '12:30', '13:00', '13:30',
#        '16:00', '17:00', '9:29', '10:26', '11:19', '13:39', '9:16',
#        '10:04', '10:42', '11:03', '9:00', '9:41', '10:17', '10:40',
# ...

# %%
df['dtUTC']=et.pac_to_utc(dts) #convert from Pac time to UTC

# %%
dtsutc=et.pac_to_utc(dts)

# %% [markdown]
# ### Start by creating a group of zooplankton taxa of interest

# %%
df['Order:'].unique()
# Out:
# array(['Diplostraca', 'Thecostraca', 'Amphipoda', 'Decapoda',
#        'Euphausiacea', 'Calanoida', 'Cyclopoida', 'Poecilostomatoida',
#        'Halocyprida', 'Aphragmophora', 'Copelata', 'Leptothecate',
#        'Siphonophorae', 'Trachylina', 'Cydippida', nan, 'Pholadomyoida',
#        'Neotaenioglossa', 'Thecosomata', 'Aciculata', 'Canalipalpata',
#        'Osmeriformes', 'Perciformes', 'Beroida', 'Teuthida',
#        'Gymnosomata', 'Isopoda', 'Siphonostomatoida', 'Anthoathecatae',
#        'Scorpaeniformes', 'Phragmophora', 'Clupeiformes', 'Ophiurida',
#        'Gadiformes', 'Semaeostomeae', 'Cumacea', 'Echinoida',
#        'Harpacticoida', 'Pleuronectiformes', 'Tricladida', 'Myodocopida',
#        'Phaeogromia', 'Noctilucales', 'Octopoda', 'Actiniaria',
#        'Foraminiferida', 'Monstrilloida', 'Oligotrichida', 'Mysida',
#        'Acariformes', 'Lophogastrida', 'Ophidiiformes',
#        'Thalassocalycida', 'Doliolida', 'Lepadomorpha', 'Cephalaspidea',
# ...

# %%
#Create a list using ALL orders so that I can look at Total Biomass of all groups
colList=('Diplostraca', 'Thecostraca', 'Amphipoda', 'Decapoda',
       'Euphausiacea', 'Calanoida', 'Cyclopoida', 'Poecilostomatoida',
       'Halocyprida', 'Aphragmophora', 'Copelata', 'Leptothecate',
       'Siphonophorae', 'Trachylina', 'Cydippida', 'Pholadomyoida',
       'Neotaenioglossa', 'Thecosomata', 'Aciculata', 'Canalipalpata',
       'Osmeriformes', 'Perciformes', 'Beroida', 'Teuthida',
       'Gymnosomata', 'Isopoda', 'Siphonostomatoida', 'Anthoathecatae',
       'Scorpaeniformes', 'Phragmophora', 'Clupeiformes', 'Ophiurida',
       'Gadiformes', 'Semaeostomeae', 'Cumacea', 'Echinoida',
       'Harpacticoida', 'Pleuronectiformes', 'Tricladida', 'Myodocopida',
       'Phaeogromia', 'Noctilucales', 'Octopoda', 'Actiniaria',
       'Foraminiferida', 'Monstrilloida', 'Oligotrichida', 'Mysida',
       'Acariformes', 'Lophogastrida', 'Ophidiiformes',
       'Thalassocalycida', 'Doliolida', 'Lepadomorpha', 'Cephalaspidea',
       'Sygnathiformes')

# %%
df.keys()
# Out:
# Index(['Key', 'region_name', 'Station', 'PROJECT', 'lon', 'lat', 'Date',
#        'STN_TIME', 'Twilight', 'Net_Type', 'Mesh_Size(um)', 'Net_Mouth_Dia(m)',
#        'DEPTH_STRT1', 'DEPTH_END1', 'Bottom Depth(m)', 'Volume Filtered(m3)',
#        'CTD', 'NOTES', 'PI', 'Phylum:', 'Class:', 'Order:', 'Family:', 'Name',
#        'Abundance(#/m3)', 'Biomass(mg/m3)', 'NumberOfSpecies',
#        'Station Diversity', 'Station Equitability', 'dtUTC'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# Key                                                      IOS2012005000901
# region_name                                    Northern Strait of Georgia
# Station                                                                22
# PROJECT                                                         Str. Geo.
# lon                                                              -124.272
# lat                                                                 49.67
# Date                                                            6/14/2012
# STN_TIME                                                             7:32
# Twilight                                                         Daylight
# Net_Type                                                         SCOR VNH
# Mesh_Size(um)                                                         236
# Net_Mouth_Dia(m)                                                     0.56
# DEPTH_STRT1                                                            50
# ...

# %%
towIDlist=['Key', 'region_name', 'Station',  'lon', 'lat','Date', 'dtUTC', 'Twilight', 'Net_Type', 'Mesh_Size(um)', 'DEPTH_STRT1', 'DEPTH_END1', 'Bottom Depth(m)']

# %%
towIDlist2=['Key', 'region_name', 'Station',  'lon', 'lat', 'Date','dtUTC', 'Twilight', 'Net_Type', 'Mesh_Size(um)', 'DEPTH_STRT1', 'DEPTH_END1', 'Bottom Depth(m)','CTD']

# %%
len(df.groupby(towIDlist)),len(df.groupby(towIDlist2)),len(df.groupby(['Key']))
# Out:
# (654, 12694, 654)

# %%
# Key is a unique identifier for each tow
# do not group by CTD due to NaN values

# %% [markdown]
# ### Create a biomass dataframe

# %%
biomassDF=df.groupby(towIDlist,as_index=False).first()\
     .loc[:,towIDlist].copy(deep=True)

# %%
biomassDF
# Out:
#                   Key                 region_name Station      lon     lat  \
# 0    IOS2012005000901  Northern Strait of Georgia      22 -124.272  49.670
# 1    IOS2012005001001  Northern Strait of Georgia      22 -124.272  49.670
# 2    IOS2012005002101  Northern Strait of Georgia      11 -124.722  49.710
# 3    IOS2012005002201  Northern Strait of Georgia      11 -124.722  49.710
# 4    IOS2012005002901  Northern Strait of Georgia    CPF2 -124.499  49.466
# ..                ...                         ...     ...      ...     ...
# 649  SOO2015095000101                 Tidal Mixed  CLO-42 -123.345  48.394
# 650  SOO2015095000401                 Tidal Mixed    CB01 -123.318  48.344
# 651  SOO2015095000501                 Tidal Mixed  CLO-41 -123.345  48.395
# 652  SOO2015095000701                 Tidal Mixed    CB01 -123.318  48.344
# 653  SOO2015095000801                 Tidal Mixed   MAC41 -123.409  48.402
#
# ...

# %%
def getbiomass(colname,key,origdf):        
    biomassArray=origdf.loc[(origdf.Key==key)&(origdf['Order:']==colname),
                    ['Biomass(mg/m3)']]
    biomass=np.nansum(biomassArray)
    
    return biomass

# %%
for icol in colList:
    biomassDF[icol]=[getbiomass(icol,ikey,df) for ikey in biomassDF['Key']]

# %%
biomassDF
# Out:
#                   Key                 region_name Station      lon     lat  \
# 0    IOS2012005000901  Northern Strait of Georgia      22 -124.272  49.670
# 1    IOS2012005001001  Northern Strait of Georgia      22 -124.272  49.670
# 2    IOS2012005002101  Northern Strait of Georgia      11 -124.722  49.710
# 3    IOS2012005002201  Northern Strait of Georgia      11 -124.722  49.710
# 4    IOS2012005002901  Northern Strait of Georgia    CPF2 -124.499  49.466
# ..                ...                         ...     ...      ...     ...
# 649  SOO2015095000101                 Tidal Mixed  CLO-42 -123.345  48.394
# 650  SOO2015095000401                 Tidal Mixed    CB01 -123.318  48.344
# 651  SOO2015095000501                 Tidal Mixed  CLO-41 -123.345  48.395
# 652  SOO2015095000701                 Tidal Mixed    CB01 -123.318  48.344
# 653  SOO2015095000801                 Tidal Mixed   MAC41 -123.409  48.402
#
# ...

# %% [markdown]
# ### Import model data for comparison with observations

# %%
import netCDF4 as nc

# %%
ftemp=nc.Dataset('/data/eolson/results/MEOPAR/NEMO-forcing-new/grid/mesh_mask201702.nc')

# %%
ftemp.variables.keys()
# Out:
# dict_keys(['nav_lon', 'nav_lat', 'time_counter', 'tmask', 'umask', 'vmask', 'fmask', 'tmaskutil', 'umaskutil', 'vmaskutil', 'fmaskutil', 'glamt', 'glamu', 'glamv', 'glamf', 'gphit', 'gphiu', 'gphiv', 'gphif', 'e1t', 'e1u', 'e1v', 'e1f', 'e2t', 'e2u', 'e2v', 'e2f', 'ff', 'mbathy', 'misf', 'isfdraft', 'e3t_0', 'e3u_0', 'e3v_0', 'e3w_0', 'gdept_0', 'gdepu', 'gdepv', 'gdepw_0', 'gdept_1d', 'gdepw_1d', 'e3t_1d', 'e3w_1d'])

# %%
ftemp.variables['e3t_0']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 e3t_0(t, z, y, x)
#     _FillValue: nan
#     standard_name: e3t_0
#     long_name: grid spacing on T-grid in w direction
#     units: m
# unlimited dimensions: t
# current shape = (1, 40, 898, 398)
# filling on

# %%
ftemp.variables['e3t_1d'][:]
# Out:
# masked_array(data=[[ 1.00000115,  1.00000501,  1.00001253,  1.00002718,
#                      1.0000557 ,  1.00011125,  1.00021946,  1.0004302 ,
#                      1.00084067,  1.00164012,  1.0031971 ,  1.00622914,
#                      1.01213271,  1.02362358,  1.04597551,  1.08940061,
#                      1.17356428,  1.33592899,  1.64636781,  2.22990285,
#                      3.29248567,  5.11998508,  7.97451506, 11.8252972 ,
#                     16.10792044, 19.95870258, 22.81323256, 24.64073198,
#                     25.70331479, 26.28684983, 26.59728865, 26.75965336,
#                     26.84381704, 26.88724213, 26.90959407, 26.92108493,
#                     26.9269885 , 26.93002054, 26.93157752, 26.93237697]],
#              mask=False,
#        fill_value=1e+20)

# %%
fdict={'ptrc_T':1,'grid_T':1}
start_date = dt.datetime(2012,1,1)
end_date = dt.datetime(2015,12,31)
flen=1 # number of days per model output file. always 1 for 201905 and 201812 model runs
namfmt='nowcast' # for 201905 and 201812 model runs, this should always be 'nowcast'
# filemap is dictionary of the form variableName: fileType, where variableName is the name
# of the variable you want to extract and fileType designates the type of 
# model output file it can be found in (usually ptrc_T for biology, grid_T for temperature and 
# salinity)
filemap={'microzooplankton':'ptrc_T','mesozooplankton':'ptrc_T'}
# fdict is a dictionary mappy file type to its time resolution. Here, 1 means hourly output
# (1h file) and 24 means daily output (1d file). In certain runs, multiple time resolutions 
# are available
fdict={'ptrc_T':1,'grid_T':1}

# %%
PATH= '/results2/SalishSea/nowcast-green.201905/'

# %%
#renaming columns to match with model columns
biomassDF.rename(columns={'lon':'Lon','lat':'Lat'},inplace=True)

# %%
biomassDF.keys()
# Out:
# Index(['Key', 'region_name', 'Station', 'Lon', 'Lat', 'Date', 'dtUTC',
#        'Twilight', 'Net_Type', 'Mesh_Size(um)', 'DEPTH_STRT1', 'DEPTH_END1',
#        'Bottom Depth(m)', 'Diplostraca', 'Thecostraca', 'Amphipoda',
#        'Decapoda', 'Euphausiacea', 'Calanoida', 'Cyclopoida',
#        'Poecilostomatoida', 'Halocyprida', 'Aphragmophora', 'Copelata',
#        'Leptothecate', 'Siphonophorae', 'Trachylina', 'Cydippida',
#        'Pholadomyoida', 'Neotaenioglossa', 'Thecosomata', 'Aciculata',
#        'Canalipalpata', 'Osmeriformes', 'Perciformes', 'Beroida', 'Teuthida',
#        'Gymnosomata', 'Isopoda', 'Siphonostomatoida', 'Anthoathecatae',
#        'Scorpaeniformes', 'Phragmophora', 'Clupeiformes', 'Ophiurida',
#        'Gadiformes', 'Semaeostomeae', 'Cumacea', 'Echinoida', 'Harpacticoida',
#        'Pleuronectiformes', 'Tricladida', 'Myodocopida', 'Phaeogromia',
#        'Noctilucales', 'Octopoda', 'Actiniaria', 'Foraminiferida',
# ...

# %%
#rename columns
biomassDF.rename(columns={'DEPTH_STRT1':'Z_lower','DEPTH_END1':'Z_upper'},inplace=True)

# %%
#create new columns
biomassDF['Year']=[ii.year for ii in biomassDF['dtUTC']]
biomassDF['Month']=[ii.month for ii in biomassDF['dtUTC']]
biomassDF['YD']=et.datetimeToYD(biomassDF['dtUTC'])

# %%
#Determine which species are making up most of the biomass in each Order
df.loc[df['Order:']=='Aphragmophora',['Name','Biomass(mg/m3)']].groupby(['Name'],as_index=False)\
        .sum().sort_values(['Biomass(mg/m3)'],ascending=False).head(50)
# Out:
#                                Name  Biomass(mg/m3)
# 4           Parasagitta elegans  s3      1016.86916
# 3           Parasagitta elegans  s2        85.99016
# 5   Parasagitta elegans juvenile s1         7.11578
# 10      Pseudosagitta scrippsae  s3         5.31616
# 7        Parasagitta euneritica  s3         3.25450
# 8            Pseudosagitta *sp.  s3         0.24895
# 1         Mesosagitta decipiens  s3         0.18561
# 2            Mesosagitta minima  s2         0.07753
# 9       Pseudosagitta scrippsae  s2         0.03206
# 6        Parasagitta euneritica  s2         0.02563
# 0         Mesosagitta decipiens  s2         0.00259

# %%
biomassSums=df.loc[df['Order:']=='Siphonophorae',['Name','Biomass(mg/m3)']].groupby(['Name'],as_index=False)\
        .sum().sort_values(['Biomass(mg/m3)'],ascending=False).reset_index()
biomassSums.head(50)
# Out:
#     index                                    Name  Biomass(mg/m3)
# 0      27             Siphonophora *sp. larvae s1       421.36818
# 1      15        Muggiaea atlantica nectophore s2       267.50799
# 2      28         Siphonophora *sp. nectophore s1       152.27508
# 3       6         Dimophyes arctica nectophore s1       128.69436
# 4       4            Dimophyes arctica eudoxid s1       117.22046
# 5      17            Nanomia bijuga nectophore s1        77.24712
# 6      13           Muggiaea atlantica eudoxid s1        76.86807
# 7       7         Dimophyes arctica nectophore s2        62.45382
# 8      16        Muggiaea atlantica nectophore s3        27.17436
# 9      25         Siphonophora *sp. gas floats s2        20.05480
# 10      5            Dimophyes arctica eudoxid s2        16.95631
# 11     24         Siphonophora *sp. gas floats s1        14.57059
# 12     14        Muggiaea atlantica nectophore s1        13.00838
# ...

# %%
biomassSums['FracAcctd']=0
for ii in range(0,len(biomassSums)):
    biomassSums.loc[ii,['FracAcctd']]=np.sum(biomassSums.loc[:(ii+1),['Biomass(mg/m3)']].values)/np.sum(biomassSums.loc[:,['Biomass(mg/m3)']].values)

# %%
biomassSums.head(50)
# Out:
#     index                                    Name  Biomass(mg/m3)  FracAcctd
# 0      27             Siphonophora *sp. larvae s1       421.36818   0.478083
# 1      15        Muggiaea atlantica nectophore s2       267.50799   0.583763
# 2      28         Siphonophora *sp. nectophore s1       152.27508   0.673078
# 3       6         Dimophyes arctica nectophore s1       128.69436   0.754429
# 4       4            Dimophyes arctica eudoxid s1       117.22046   0.808039
# 5      17            Nanomia bijuga nectophore s1        77.24712   0.861386
# 6      13           Muggiaea atlantica eudoxid s1        76.86807   0.904729
# 7       7         Dimophyes arctica nectophore s2        62.45382   0.923588
# 8      16        Muggiaea atlantica nectophore s3        27.17436   0.937507
# 9      25         Siphonophora *sp. gas floats s2        20.05480   0.949274
# 10      5            Dimophyes arctica eudoxid s2        16.95631   0.959386
# ...

# %%
biomassDF['Amphipoda'].unique()[1:20]
# Out:
# array([  2.57318,   8.45483,  23.57762, 124.3143 ,  17.99728,   4.55559,
#         10.63095,  10.09762,  12.90642,  27.23425,  25.01763,   9.29238,
#         10.05655,  30.55784,  10.18829,   4.94119,   9.72043,   1.85966,
#         21.15174])

# %% [markdown]
# #### Need to convert biomass from mg DW to mg C (use 0.45 conversion factor)

# %%
biomassDF['Total']=((biomassDF['Diplostraca']+biomassDF['Thecostraca']+biomassDF['Amphipoda']+\
                    biomassDF['Decapoda']+biomassDF['Euphausiacea']+\
                    biomassDF['Calanoida']+biomassDF['Cyclopoida']+biomassDF['Poecilostomatoida']+\
                    biomassDF['Halocyprida']+biomassDF['Aphragmophora']+biomassDF['Copelata']+\
                   biomassDF['Leptothecate']+biomassDF['Siphonophorae']+biomassDF['Trachylina']+\
                   biomassDF['Cydippida']+biomassDF['Pholadomyoida']+biomassDF['Neotaenioglossa']+\
                   biomassDF['Thecosomata']+biomassDF['Aciculata']+biomassDF['Canalipalpata']+\
                   biomassDF['Osmeriformes']+biomassDF['Perciformes']+biomassDF['Beroida']+\
                   biomassDF['Teuthida']+biomassDF['Gymnosomata']+biomassDF['Isopoda']+\
                   biomassDF['Siphonostomatoida']+biomassDF['Anthoathecatae']+biomassDF['Scorpaeniformes']+\
                   biomassDF['Phragmophora']+biomassDF['Clupeiformes']+biomassDF['Ophiurida']+\
                   biomassDF['Gadiformes']+biomassDF['Semaeostomeae']+biomassDF['Cumacea']+\
                   biomassDF['Echinoida']+biomassDF['Harpacticoida']+biomassDF['Pleuronectiformes']+\
                   biomassDF['Tricladida']+biomassDF['Myodocopida']+biomassDF['Phaeogromia']+\
                   biomassDF['Noctilucales']+biomassDF['Octopoda']+biomassDF['Actiniaria']+\
                   biomassDF['Foraminiferida']+biomassDF['Monstrilloida']+biomassDF['Oligotrichida']+\
                   biomassDF['Mysida']+biomassDF['Acariformes']+biomassDF['Lophogastrida']+\
                   biomassDF['Ophidiiformes']+biomassDF['Thalassocalycida']+biomassDF['Doliolida']+\
                   biomassDF['Lepadomorpha']+biomassDF['Cephalaspidea']+biomassDF['Sygnathiformes'])*0.45)

# %% [raw]
#   List of Order names:
#        'Diplostraca', 'Thecostraca', 'Amphipoda', 'Decapoda',
#        'Euphausiacea', 'Calanoida', 'Cyclopoida', 'Poecilostomatoida',
#        'Halocyprida', 'Aphragmophora', 'Copelata', 'Leptothecate',
#        'Siphonophorae', 'Trachylina', 'Cydippida', 'Pholadomyoida',
#        'Neotaenioglossa', 'Thecosomata', 'Aciculata', 'Canalipalpata',
#        'Osmeriformes', 'Perciformes', 'Beroida', 'Teuthida',
#        'Gymnosomata', 'Isopoda', 'Siphonostomatoida', 'Anthoathecatae',
#        'Scorpaeniformes', 'Phragmophora', 'Clupeiformes', 'Ophiurida',
#        'Gadiformes', 'Semaeostomeae', 'Cumacea', 'Echinoida',
#        'Harpacticoida', 'Pleuronectiformes', 'Tricladida', 'Myodocopida',
#        'Phaeogromia', 'Noctilucales', 'Octopoda', 'Actiniaria',
#        'Foraminiferida', 'Monstrilloida', 'Oligotrichida', 'Mysida',
#        'Acariformes', 'Lophogastrida', 'Ophidiiformes',
#        'Thalassocalycida', 'Doliolida', 'Lepadomorpha', 'Cephalaspidea',
#        'Sygnathiformes'

# %%
#Create column of the Main Groups based on biomass-dominant species
biomassDF['MainGroups']=((biomassDF['Amphipoda']+\
                    biomassDF['Decapoda']+biomassDF['Euphausiacea']+\
                    biomassDF['Calanoida']+biomassDF['Copelata']+biomassDF['Aphragmophora'])*0.45)

# %%
#All other groups not included in 'Main Groups'
biomassDF['OtherGroups']=((biomassDF['Diplostraca']+biomassDF['Thecostraca']+\
                    biomassDF['Cyclopoida']+biomassDF['Poecilostomatoida']+\
                    biomassDF['Halocyprida']+\
                   biomassDF['Leptothecate']+biomassDF['Siphonophorae']+biomassDF['Trachylina']+\
                   biomassDF['Cydippida']+biomassDF['Pholadomyoida']+biomassDF['Neotaenioglossa']+\
                   biomassDF['Thecosomata']+biomassDF['Aciculata']+biomassDF['Canalipalpata']+\
                   biomassDF['Osmeriformes']+biomassDF['Perciformes']+biomassDF['Beroida']+\
                   biomassDF['Teuthida']+biomassDF['Gymnosomata']+biomassDF['Isopoda']+\
                   biomassDF['Siphonostomatoida']+biomassDF['Anthoathecatae']+biomassDF['Scorpaeniformes']+\
                   biomassDF['Phragmophora']+biomassDF['Clupeiformes']+biomassDF['Ophiurida']+\
                   biomassDF['Gadiformes']+biomassDF['Semaeostomeae']+biomassDF['Cumacea']+\
                   biomassDF['Echinoida']+biomassDF['Harpacticoida']+biomassDF['Pleuronectiformes']+\
                   biomassDF['Tricladida']+biomassDF['Myodocopida']+biomassDF['Phaeogromia']+\
                   biomassDF['Noctilucales']+biomassDF['Octopoda']+biomassDF['Actiniaria']+\
                   biomassDF['Foraminiferida']+biomassDF['Monstrilloida']+biomassDF['Oligotrichida']+\
                   biomassDF['Mysida']+biomassDF['Acariformes']+biomassDF['Lophogastrida']+\
                   biomassDF['Ophidiiformes']+biomassDF['Thalassocalycida']+biomassDF['Doliolida']+\
                   biomassDF['Lepadomorpha']+biomassDF['Cephalaspidea']+biomassDF['Sygnathiformes'])*0.45)

# %%
#Create columns for specific groups of interest using slightly diff names to avoid overwriting original columns
biomassDF['Amphipods']=biomassDF['Amphipoda']*0.45
biomassDF['Decapods']=biomassDF['Decapoda']*0.45
biomassDF['Euphausiids']=biomassDF['Euphausiacea']*0.45
biomassDF['Calanoids']=biomassDF['Calanoida']*0.45
biomassDF['Cyclopoids']=biomassDF['Cyclopoida']*0.45
biomassDF['Poecilostomatoids']=biomassDF['Poecilostomatoida']*0.45
biomassDF['Larvaceans']=biomassDF['Copelata']*0.45
biomassDF['Harpacticoids']=biomassDF['Harpacticoida']*0.45

# %%
biomassDF2013=biomassDF[biomassDF.Year==2013]

# %%
biomassDF2013
# Out:
#                   Key                 region_name Station      Lon     Lat  \
# 54   IOS2013012001701   Central Strait of Georgia      41 -123.372  49.055
# 55   IOS2013012001801   Central Strait of Georgia      41 -123.389  49.055
# 56   IOS2013012002501   Central Strait of Georgia    CPF1 -124.086  49.367
# 57   IOS2013012002601   Central Strait of Georgia    CPF1 -124.088  49.367
# 58   IOS2013012003101  Northern Strait of Georgia    CPF2 -124.500  49.467
# ..                ...                         ...     ...      ...     ...
# 492  PBS2013043000401   Central Strait of Georgia    GS01 -123.398  48.936
# 493  PBS2013043005701  Northern Strait of Georgia    GS11 -124.569  49.484
# 494  PBS2013045000201   Central Strait of Georgia    CPF1 -124.077  49.370
# 495  PBS2013045000401   Central Strait of Georgia    GEO1 -123.750  49.249
# 496  PBS2013045000801   Central Strait of Georgia    GS02 -123.451  49.001
#
# ...

# %%
#Match observation data with model output
##Error warning is fine as long as the difference between seafloor value is <3ish
data=et.matchData(biomassDF,filemap,fdict,start_date,end_date,'nowcast',PATH,1,quiet=False,method='vertNet');

# %%
data
# Out:
#                   Key                 region_name Station      Lon     Lat  \
# 0    IOS2012025013601  Northern Strait of Georgia    CPF2 -124.501  49.467
# 1    IOS2012025013701  Northern Strait of Georgia    CPF2 -124.501  49.467
# 2    IOS2012025013702  Northern Strait of Georgia    CPF2 -124.501  49.467
# 3    IOS2012025013703  Northern Strait of Georgia    CPF2 -124.501  49.467
# 4    IOS2012025013704  Northern Strait of Georgia    CPF2 -124.501  49.467
# ..                ...                         ...     ...      ...     ...
# 649  PSF2015097005001  Northern Strait of Georgia    IS-3 -124.287  49.655
# 650  PSF2015098005701  Northern Strait of Georgia    BS-3 -124.666  49.692
# 651  PSF2015098005801                Baynes Sound    BS-1 -124.867  49.608
# 652  PSF2015097005101        Nearshore-North East    IS-2 -124.083  49.637
# 653  PSF2015098005901                Baynes Sound    BS-7 -124.767  49.483
#
# ...

# %%
data.keys()
# Out:
# Index(['Key', 'region_name', 'Station', 'Lon', 'Lat', 'Date', 'dtUTC',
#        'Twilight', 'Net_Type', 'Mesh_Size(um)', 'Z_lower', 'Z_upper',
#        'Bottom Depth(m)', 'Diplostraca', 'Thecostraca', 'Amphipoda',
#        'Decapoda', 'Euphausiacea', 'Calanoida', 'Cyclopoida',
#        'Poecilostomatoida', 'Halocyprida', 'Aphragmophora', 'Copelata',
#        'Leptothecate', 'Siphonophorae', 'Trachylina', 'Cydippida',
#        'Pholadomyoida', 'Neotaenioglossa', 'Thecosomata', 'Aciculata',
#        'Canalipalpata', 'Osmeriformes', 'Perciformes', 'Beroida', 'Teuthida',
#        'Gymnosomata', 'Isopoda', 'Siphonostomatoida', 'Anthoathecatae',
#        'Scorpaeniformes', 'Phragmophora', 'Clupeiformes', 'Ophiurida',
#        'Gadiformes', 'Semaeostomeae', 'Cumacea', 'Echinoida', 'Harpacticoida',
#        'Pleuronectiformes', 'Tricladida', 'Myodocopida', 'Phaeogromia',
#        'Noctilucales', 'Octopoda', 'Actiniaria', 'Foraminiferida',
# ...

# %%
# define log transform function with slight shift to accommodate zero values
def logt(x):
  return np.log10(x+.001)

# %%
# define inverse log transform with same shift
def logt_inv(y):
    return 10**y-.001

# %%
#create columns for log10 +0.001 transformed zooplankton
data['L10Amphipods']=logt(data['Amphipods'])
data['L10Decapods']=logt(data['Decapods'])
data['L10Euphausiids']=logt(data['Euphausiids']*3) #multiply by 3 to correct for net avoidance
data['L10Calanoids']=logt(data['Calanoids'])
data['L10Cyclopoids']=logt(data['Cyclopoids'])
data['L10Poecilostomatoids']=logt(data['Poecilostomatoids'])
data['L10Larvaceans']=logt(data['Larvaceans'])
data['L10Harpacticoids']=logt(data['Harpacticoids'])
data['L10Total']=logt(data['Total'])
data['L10MainGroups']=logt(data['MainGroups'])
data['L10OtherGroups']=logt(data['OtherGroups'])

#Convert model values to mg C m-3 by multiplying value * C:N of 5.7 * molecular weight of C (12)
data['L10mod_mesozooplankton']=logt(data['mod_mesozooplankton']*5.7*12)
data['L10mod_microzooplankton']=logt(data['mod_microzooplankton']*5.7*12)

# %%
#look at data for individual years
View2012=data.loc[data.Year==2012]
View2013=data.loc[data.Year==2013]
View2014=data.loc[data.Year==2014]
View2015=data.loc[data.Year==2015]

# %%
#look at data for a specific region
ViewCentralSoG=data.loc[data.region_name=='Central Strait of Georgia']
ViewNorthernSoG=data.loc[data.region_name=='Northern Strait of Georgia']
ViewSouthernSoG=data.loc[data.region_name=='Southern Strait of Georgia']
ViewBaynes=data.loc[data.region_name=='Baynes Sound']
ViewTidalMixed=data.loc[data.region_name=='Tidal Mixed']
ViewNearshoreNE=data.loc[data.region_name=='Nearshore-North East']

# %%
#look at data for an individual station
ViewGEO1=data.loc[data.Station=='GEO1']

# %%
View2015
# Out:
#                    Key                 region_name  Station      Lon     Lat  \
# 310  IOS2015001000201A                 Tidal Mixed       59 -123.245  48.614
# 311  IOS2015001000701A                Juan de Fuca     JF02 -124.002  48.300
# 312   IOS2015099000101  Northern Strait of Georgia  GEO_STR -124.092  49.583
# 313   IOS2015099000201   Central Strait of Georgia     GEO1 -123.748  49.252
# 314   IOS2015099000301  Northern Strait of Georgia       11 -124.718  49.705
# ..                 ...                         ...      ...      ...     ...
# 649   PSF2015097005001  Northern Strait of Georgia     IS-3 -124.287  49.655
# 650   PSF2015098005701  Northern Strait of Georgia     BS-3 -124.666  49.692
# 651   PSF2015098005801                Baynes Sound     BS-1 -124.867  49.608
# 652   PSF2015097005101        Nearshore-North East     IS-2 -124.083  49.637
# 653   PSF2015098005901                Baynes Sound     BS-7 -124.767  49.483
#
# ...

# %% [raw]
# #old groupings after following a tutorial (ignore as I have streamlined this below)
# monthCala=data.groupby(['Month', 'Calanoida'], as_index=False).mean()
# monthEuph=data.groupby(['Month', 'Euphausiacea'], as_index=False).mean()
# monthAmph=data.groupby(['Month', 'Amphipoda'], as_index=False).mean()
# monthCrab=data.groupby(['Month', 'Decapoda'], as_index=False).mean()
# monthNonCala=data.groupby(['Month', 'Poecilostomatoida'], as_index=False).mean()
# monthLarv=data.groupby(['Month', 'Copelata'], as_index=False).mean()
# monthModMicro=data.groupby(['Month', 'mod_microzooplankton'], as_index=False).mean()
# monthModMeso=data.groupby(['Month', 'mod_mesozooplankton'], as_index=False).mean()
# monthTotal=data.groupby(['Month', 'Total'], as_index=False).mean()
# monthTotalCalRemoved=data.groupby(['Month', 'TotalCalRemoved'], as_index=False).mean()

# %% [markdown]
# ### Calculate Mean and SEMs

# %%
#monthly mean and SEM for entire SoG
monthlymean=data.groupby(['Month']).mean()

# %%
monthlysem=data.groupby(['Month']).sem()

# %%
#monthly mean and SEM for Central SoG Only
monthlymeanCentral=ViewCentralSoG.groupby(['Month']).mean()
monthlymeanBaynes=ViewBaynes.groupby(['Month']).mean()
monthlymeanNorthern=ViewNorthernSoG.groupby(['Month']).mean()
monthlymeanSouthern=ViewSouthernSoG.groupby(['Month']).mean()
monthlymeanTidal=ViewTidalMixed.groupby(['Month']).mean()
monthlymeanNearshoreNE=ViewNearshoreNE.groupby(['Month']).mean()

# %%
monthlysemCentral=ViewCentralSoG.groupby(['Month']).sem()

# %%
#monthly mean and SEM for station GEO1 only
monthlymeanGEO1=ViewGEO1.groupby(['Month']).mean()

# %%
monthlysemGEO1=ViewGEO1.groupby(['Month']).sem()

# %%
monthlymean2012=View2012.groupby(['Month']).mean()
monthlymean2013=View2013.groupby(['Month']).mean()
monthlymean2014=View2014.groupby(['Month']).mean()
monthlymean2015=View2015.groupby(['Month']).mean()

# %%
monthlysem2012=View2012.groupby(['Month']).sem()
monthlysem2013=View2013.groupby(['Month']).sem()
monthlysem2014=View2014.groupby(['Month']).sem()
monthlysem2015=View2015.groupby(['Month']).sem()

# %% [markdown]
# ## Figure showing observation locations of IOS zooplankton sampling

# %%
fig, ax = plt.subplots(1,1,figsize = (6,6))
with nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/bathymetry_201702.nc') as grid:
    viz_tools.plot_coastline(ax, grid, coords = 'map',isobath=.1)
colors=('teal','green','firebrick','darkorange','darkviolet','fuchsia',
        'royalblue','darkgoldenrod','mediumspringgreen','deepskyblue','lightblue')
datreg=dict()
for ind, iregion in enumerate(data.region_name.unique()):
    datreg[iregion] = data.loc[data.region_name==iregion]
    ax.plot(datreg[iregion]['Lon'], datreg[iregion]['Lat'],'.',
            color = colors[ind], label=iregion)
ax.set_ylim(47,51)
ax.legend(bbox_to_anchor=[1,.6,0,0])
ax.set_xlim(-126, -120);
ax.set_title('Observation Locations');
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %%
np.shape([monthlymean['L10Total']-monthlysem['L10Total'],
 monthlymean['L10Total']+monthlysem['L10Total']])
# Out:
# (2, 9)

# %% [markdown]
# ### Plot biomass of individual groups for entire Strait of Georgia

# %%
fig,ax=plt.subplots(1,3,figsize=(20,5))
fig.suptitle('Strait of Georgia', fontsize=24)
fig.subplots_adjust(top=0.8)
ax[0].errorbar(monthlymean.index,logt_inv(monthlymean['L10Calanoids']),
               yerr=logt_inv(np.array([monthlymean['L10Calanoids']-monthlysem['L10Calanoids'],
                 monthlymean['L10Calanoids']+monthlysem['L10Calanoids']])),
               fmt='ro',capsize=5)
ax[0].plot(logt_inv(monthlymean['L10Calanoids']),'b--')
ax[1].errorbar(monthlymean.index,logt_inv(monthlymean['L10Euphausiids']),
               yerr=logt_inv(np.array([monthlymean['L10Euphausiids']-monthlysem['L10Euphausiids'],
                 monthlymean['L10Euphausiids']+monthlysem['L10Euphausiids']])),
               fmt='ro',capsize=5)
ax[1].plot(logt_inv(monthlymean['L10Euphausiids']),'b--')
ax[2].errorbar(monthlymean.index,logt_inv(monthlymean['L10Amphipods']),
               yerr=logt_inv(np.array([monthlymean['L10Amphipods']-monthlysem['L10Amphipods'],
                 monthlymean['L10Amphipods']+monthlysem['L10Amphipods']])),
               fmt='ro',capsize=5)
ax[2].plot(logt_inv(monthlymean['L10Amphipods']),'b--')
ax[0].set_title('Calanoid Seasonal Cycle')
ax[1].set_title('Euphausiid Seasonal Cycle')
ax[2].set_title('Amphipod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,15)
ax[1].set_ylim(0,10)
ax[2].set_ylim(0,10)

fig,ax=plt.subplots(1,3,figsize=(20,5))
ax[0].errorbar(monthlymean.index,logt_inv(monthlymean['L10Poecilostomatoids']),
               yerr=logt_inv(np.array([monthlymean['L10Poecilostomatoids']-monthlysem['L10Poecilostomatoids'],
                 monthlymean['L10Poecilostomatoids']+monthlysem['L10Poecilostomatoids']])),
               fmt='ro',capsize=5)
ax[0].plot(logt_inv(monthlymean['L10Poecilostomatoids']),'b--')
ax[1].errorbar(monthlymean.index,logt_inv(monthlymean['L10Larvaceans']),
               yerr=logt_inv(np.array([monthlymean['L10Larvaceans']-monthlysem['L10Larvaceans'],
                 monthlymean['L10Larvaceans']+monthlysem['L10Larvaceans']])),
               fmt='ro',capsize=5)
ax[1].plot(logt_inv(monthlymean['L10Larvaceans']),'b--')
ax[2].errorbar(monthlymean.index,logt_inv(monthlymean['L10Decapods']),
               yerr=logt_inv(np.array([monthlymean['L10Decapods']-monthlysem['L10Decapods'],
                 monthlymean['L10Decapods']+monthlysem['L10Decapods']])),
               fmt='ro',capsize=5)
ax[2].plot(logt_inv(monthlymean['L10Decapods']),'b--')
ax[0].set_title('Non Calanoid Seasonal Cycle')
ax[1].set_title('Larvacean Seasonal Cycle')
ax[2].set_title('Gastropod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,5)
ax[1].set_ylim(0,5)
ax[2].set_ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### Plot biomass of individual groups for Central Strait of Georgia

# %%
fig,ax=plt.subplots(1,3,figsize=(20,5))
fig.suptitle('Central SoG', fontsize=24)
fig.subplots_adjust(top=0.8)
ax[0].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Calanoids']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Calanoids']-monthlysemCentral['L10Calanoids'],
                 monthlymeanCentral['L10Calanoids']+monthlysemCentral['L10Calanoids']])),
               fmt='o',color='gray',capsize=5)
ax[0].plot(logt_inv(monthlymeanCentral['L10Calanoids']),'b-')
ax[1].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Euphausiids']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Euphausiids']-monthlysemCentral['L10Euphausiids'],
                 monthlymeanCentral['L10Euphausiids']+monthlysemCentral['L10Euphausiids']])),
               fmt='o',color='gray',capsize=5)
ax[1].plot(logt_inv(monthlymeanCentral['L10Euphausiids']),'b-')
ax[2].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Amphipods']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Amphipods']-monthlysemCentral['L10Amphipods'],
                 monthlymeanCentral['L10Amphipods']+monthlysemCentral['L10Amphipods']])),
               fmt='o',color='gray',capsize=5)
ax[2].plot(logt_inv(monthlymeanCentral['L10Amphipods']),'b-')
ax[0].set_title('Calanoid Seasonal Cycle')
ax[1].set_title('Euphausiid Seasonal Cycle')
ax[2].set_title('Amphipod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,20)
ax[1].set_ylim(0,20)
ax[2].set_ylim(0,20)

fig,ax=plt.subplots(1,3,figsize=(20,5))
ax[0].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Poecilostomatoids']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Poecilostomatoids']-monthlysemCentral['L10Poecilostomatoids'],
                 monthlymeanCentral['L10Poecilostomatoids']+monthlysemCentral['L10Poecilostomatoids']])),
               fmt='o',color='gray',capsize=5)
ax[0].plot(logt_inv(monthlymeanCentral['L10Poecilostomatoids']),'b-')
ax[1].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Larvaceans']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Larvaceans']-monthlysemCentral['L10Larvaceans'],
                 monthlymeanCentral['L10Larvaceans']+monthlysemCentral['L10Larvaceans']])),
               fmt='o',color='gray',capsize=5)
ax[1].plot(logt_inv(monthlymeanCentral['L10Larvaceans']),'b-')
ax[2].errorbar(monthlymeanCentral.index,logt_inv(monthlymeanCentral['L10Decapods']),
               yerr=logt_inv(np.array([monthlymeanCentral['L10Decapods']-monthlysemCentral['L10Decapods'],
                 monthlymeanCentral['L10Decapods']+monthlysemCentral['L10Decapods']])),
               fmt='o',color='gray',capsize=5)
ax[2].plot(logt_inv(monthlymeanCentral['L10Decapods']),'b-')
ax[0].set_title('Non Calanoid Seasonal Cycle')
ax[1].set_title('Larvacean Seasonal Cycle')
ax[2].set_title('Gastropod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,5)
ax[1].set_ylim(0,5)
ax[2].set_ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### Plot biomass of individual groups for station GEO1 in Central Strait of Georgia

# %%
fig,ax=plt.subplots(1,3,figsize=(20,5))
fig.suptitle('GEO1', fontsize=24)
fig.subplots_adjust(top=0.8)
ax[0].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Calanoids']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Calanoids']-monthlysemGEO1['L10Calanoids'],
                 monthlymeanGEO1['L10Calanoids']+monthlysemGEO1['L10Calanoids']])),
               fmt='o',color='gray',capsize=5)
ax[0].plot(logt_inv(monthlymeanGEO1['L10Calanoids']),'b--')
ax[1].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Euphausiids']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Euphausiids']-monthlysemGEO1['L10Euphausiids'],
                 monthlymeanGEO1['L10Euphausiids']+monthlysemGEO1['L10Euphausiids']])),
               fmt='o',color='gray',capsize=5)
ax[1].plot(logt_inv(monthlymeanGEO1['L10Euphausiids']),'b--')
ax[2].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Amphipods']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Amphipods']-monthlysemGEO1['L10Amphipods'],
                 monthlymeanGEO1['L10Amphipods']+monthlysemGEO1['L10Amphipods']])),
               fmt='o',color='gray',capsize=5)
ax[2].plot(logt_inv(monthlymeanGEO1['L10Amphipods']),'b--')
ax[0].set_title('Calanoid Seasonal Cycle')
ax[1].set_title('Euphausiid Seasonal Cycle')
ax[2].set_title('Amphipod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,30)
ax[1].set_ylim(0,30)
ax[2].set_ylim(0,30)

fig,ax=plt.subplots(1,3,figsize=(20,5))
ax[0].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Poecilostomatoids']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Poecilostomatoids']-monthlysemGEO1['L10Poecilostomatoids'],
                 monthlymeanGEO1['L10Poecilostomatoids']+monthlysemGEO1['L10Poecilostomatoids']])),
               fmt='o',color='gray',capsize=5)
ax[0].plot(logt_inv(monthlymeanGEO1['L10Poecilostomatoids']),'b--')
ax[1].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Larvaceans']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Larvaceans']-monthlysemGEO1['L10Larvaceans'],
                 monthlymeanGEO1['L10Larvaceans']+monthlysemGEO1['L10Larvaceans']])),
               fmt='o',color='gray',capsize=5)
ax[1].plot(logt_inv(monthlymeanGEO1['L10Larvaceans']),'b--')
ax[2].errorbar(monthlymeanGEO1.index,logt_inv(monthlymeanGEO1['L10Decapods']),
               yerr=logt_inv(np.array([monthlymeanGEO1['L10Decapods']-monthlysemGEO1['L10Decapods'],
                 monthlymeanGEO1['L10Decapods']+monthlysemGEO1['L10Decapods']])),
               fmt='o',color='gray',capsize=5)
ax[2].plot(logt_inv(monthlymeanGEO1['L10Decapods']),'b--')
ax[0].set_title('Non Calanoid Seasonal Cycle')
ax[1].set_title('Larvacean Seasonal Cycle')
ax[2].set_title('Gastropod Seasonal Cycle')
ax[0].set_ylabel('Mean Biomass (mg C m-3)')
ax[0].set_xlim(0,12)
ax[1].set_xlim(0,12)
ax[2].set_xlim(0,12)
ax[0].set_ylim(0,5)
ax[1].set_ylim(0,5)
ax[2].set_ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### Plot seasonal cycles of Model vs Obs for different regions in Strait of Georgia

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymean['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,60)
ax.set_xlim(0,12)
ax.set_title('Strait of Georgia Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,60)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,60)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNorthern['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanNorthern['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Northern SoG Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNorthern['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNorthern['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanCentral['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanCentral['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Central SoG Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanCentral['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanCentral['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,50)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanSouthern['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanSouthern['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Southern SoG Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanSouthern['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanSouthern['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNearshoreNE['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanNearshoreNE['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Nearshore NE Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNearshoreNE['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanNearshoreNE['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanBaynes['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanBaynes['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,250)
ax.set_xlim(0,12)
ax.set_title('Baynes Sound Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanBaynes['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,250)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanBaynes['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,250)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanTidal['L10Total']),'--',color='blue',label='Total Zooplankton')
ax.plot(logt_inv(monthlymeanTidal['L10MainGroups']),'--',color='lightblue',label='Main Groups')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Tidal Mixed Observation Zooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanTidal['L10mod_mesozooplankton']),'--',color='red',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymeanTidal['L10mod_microzooplankton']),'--',color='darkorange',label='Model Microzoop')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton Seasonal Cycle')
ax.set_ylabel('Mean Biomass (mg C m-3)',fontsize=10)
# Out:
# Text(0, 0.5, 'Mean Biomass (mg C m-3)')

# %%
fig,ax=plt.subplots(1,1,figsize=(12,2.5))

ax.plot(logt_inv(monthlymean2013['L10Total']),'-',color='blue',label='2013')
ax.plot(logt_inv(monthlymean2014['L10Total']),'-.',color='orange',label='2014')
ax.plot(logt_inv(monthlymean2015['L10Total']),'--',color='green',label='2015')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('SoG Obs with Calanoids')
ax.set_ylabel('Mean Biomass ($\mu$M N)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean2013['L10MainGroups']),'-',color='blue',label='2013')
ax.plot(logt_inv(monthlymean2014['L10MainGroups']),'-.',color='orange',label='2014')
ax.plot(logt_inv(monthlymean2015['L10MainGroups']),'--',color='green',label='2015')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('SoG Obs Main Groups')
ax.set_ylabel('Mean Biomass ($\mu$M N)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean2013['L10mod_mesozooplankton']),'-',color='blue',label='2013')
ax.plot(logt_inv(monthlymean2014['L10mod_mesozooplankton']),'-.',color='orange',label='2014')
ax.plot(logt_inv(monthlymean2015['L10mod_mesozooplankton']),'--',color='green',label='2015')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Mesozooplankton')
ax.set_ylabel('Mean Biomass ($\mu$M N)',fontsize=10)
ax.legend(fontsize=10)

fig,ax=plt.subplots(1,1,figsize=(12,2.5))
ax.plot(logt_inv(monthlymean2013['L10mod_microzooplankton']),'-',color='blue',label='2013')
ax.plot(logt_inv(monthlymean2014['L10mod_microzooplankton']),'-.',color='orange',label='2014')
ax.plot(logt_inv(monthlymean2015['L10mod_microzooplankton']),'--',color='green',label='2015')
ax.set_ylim(0,100)
ax.set_xlim(0,12)
ax.set_title('Model Microzooplankton')
ax.set_ylabel('Mean Biomass ($\mu$M N)',fontsize=10)
ax.legend(fontsize=10)

# %%
cm1=cmocean.cm.thermal
with nc.Dataset('/ocean/ksuchy/MOAD/NEMO-forcing/grid/bathymetry_201702.nc') as bathy:
    bathylon=np.copy(bathy.variables['nav_lon'][:,:])
    bathylat=np.copy(bathy.variables['nav_lat'][:,:])
    bathyZ=np.copy(bathy.variables['Bathymetry'][:,:])

# %%
def yd(idt):
    if type(idt)==dt.datetime:
        yd=(idt-dt.datetime(idt.year-1,12,31)).days
    else: # assume array or pandas
        yd=[(ii-dt.datetime(ii.year-1,12,31)).days for ii in idt]
    return yd

data['yd']=yd(data['dtUTC'])
data['Year']=[ii.year for ii in data['dtUTC']]

# %% [markdown]
# #### By Day of Year

# %%
fig,ax=plt.subplots(1,1,figsize=(7,7))
m=ax.scatter((data['L10Total']),(data['L10mod_mesozooplankton']),
          c=data['yd'],s=5,cmap=cmocean.cm.phase)

ax.set_title('log10[ Total + 0.001] By Year Day')
ax.set_xlabel('Obs')
ax.set_ylabel('Model')
ax.plot((-6,5),(-6,5),'r-',alpha=.3)
ax.set_xlim(-1.5,3)
ax.set_ylim(-1.5,3);
fig.colorbar(m)

# %%
data['Month']=[ii.month for ii in data['dtUTC']]
JF=data.loc[(data.Month==1)|(data.Month==2)]
MAM=data.loc[(data.Month==3)|(data.Month==4)|(data.Month==5)]
JJA=data.loc[(data.Month==6)|(data.Month==7)|(data.Month==8)]
SOND=data.loc[(data.Month==9)|(data.Month==10)|(data.Month==11)|(data.Month==12)]

# %%
def byRegion(ax,obsvar,modvar,lims):
    SoG=[]
    for ind, iregion in enumerate(data.region_name.unique()):
        #ax.plot(datreg[iregion]['Lon'], datreg[iregion]['Lat'],'.',
                #color = colors[ind], label=iregion)
        SoG0=et.varvarPlot(ax,datreg[iregion],obsvar,modvar,
                          cols=(colors[ind],),lname=iregion)
        SoG.append(SoG0)
        
    l=ax.legend(handles=[ip[0][0] for ip in SoG])
    ax.set_xlabel('Obs')
    ax.set_ylabel('Model')
    ax.plot(lims,lims,'k-',alpha=.5)
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    ax.set_aspect(1)
    return SoG,l

# %%
def bySeason(ax,obsvar,modvar,lims):
    for axi in ax:
        axi.plot(lims,lims,'k-')
        axi.set_xlim(lims)
        axi.set_ylim(lims)
        axi.set_aspect(1)
        axi.set_xlabel('Obs')
        axi.set_ylabel('Model')
    SoG=et.varvarPlot(ax[0],JF,obsvar,modvar,cols=('crimson','darkturquoise','navy'))
    ax[0].set_title('Winter')
    SoG=et.varvarPlot(ax[1],MAM,obsvar,modvar,cols=('crimson','darkturquoise','navy'))
    ax[1].set_title('Spring')
    SoG=et.varvarPlot(ax[2],JJA,obsvar,modvar,cols=('crimson','darkturquoise','navy'))
    ax[2].set_title('Summer')
    SoG=et.varvarPlot(ax[3],SOND,obsvar,modvar,cols=('crimson','darkturquoise','navy'))
    ax[3].set_title('Autumn')
    return

# %% [markdown]
# ### Plots of Total Zooplankton vs. model mesozooplankton by Region

# %%
fig, ax = plt.subplots(1,1,figsize = (16,7))     
SoG,l=byRegion(ax,'L10Total','L10mod_mesozooplankton',(-1,3))
ax.set_title('Log 10 Total + 0.001 (mg C m-3) By Region')
ax.legend(bbox_to_anchor=(1.1, 1.05))
fig.savefig('TotalZoopModelvsObsSoG.png',bbox_inches='tight')

fig, ax = plt.subplots(1,4,figsize = (16,3.3))
bySeason(ax,'L10Total','L10mod_mesozooplankton',(-1,3))

# %%
fig, ax = plt.subplots(1,1,figsize = (16,7))     
SoG,l=byRegion(ax,'L10MainGroups','L10mod_mesozooplankton',(-1,3))
ax.set_title('Log 10 Main Groups + 0.001 (mg C m-3) By Region')
ax.legend(bbox_to_anchor=(1.1, 1.05))

fig, ax = plt.subplots(1,4,figsize = (16,3.3))
bySeason(ax,'L10MainGroups','L10mod_mesozooplankton',(-1,3))

# %%
fig, ax = plt.subplots(1,1,figsize = (16,7))     
SoG,l=byRegion(ax,'L10OtherGroups','L10mod_mesozooplankton',(-1,3))
ax.set_title('Log 10 Other Groups + 0.001 (mg C m-3) By Region')
ax.legend(bbox_to_anchor=(1.1, 1.05))

fig, ax = plt.subplots(1,4,figsize = (16,3.3))
bySeason(ax,'L10OtherGroups','L10mod_mesozooplankton',(-1,3))

# %% [markdown]
# ####

# %%
fig,ax=plt.subplots(1,3,figsize=(15,7))
fig.subplots_adjust(wspace=.4)
fig.subplots_adjust(hspace=.6)
ax=ax.flatten()

taxa=('L10Total', 'L10MainGroups','L10OtherGroups')

mvar1=data['L10mod_microzooplankton']
mvar2=data['L10mod_mesozooplankton']

for ii in range(0,len(taxa)):
    ax[ii].plot((data.loc[:,[taxa[ii]]].values),(mvar1),'.',ms=1,color='blue',label='Microzoop')
    ax[ii].plot((data.loc[:,[taxa[ii]]].values),(mvar2),'.',ms=1,color='red',label='Mesozoop')
    ax[ii].set_ylabel('Model Class')
    ax[ii].set_xlabel(taxa[ii])
    ax[ii].set_title('mg C m-3')
    ax[ii].plot((-3,3),(-3,3),'k-',alpha=.2)
    ax[ii].set_xlim((-1,3))
    ax[ii].set_ylim((-1,3))
    ax[ii].set_aspect(1)
ax[0].legend(loc=2, fontsize = 'medium')
